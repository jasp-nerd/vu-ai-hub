# %% [markdown]
# # Pre-exam Practice Intro to Python 2023

# %% [markdown]
# ## Instructions & Remarks
#
# * Excersises are split by the difficulty level, 1 being the easiest 3 being the hardest.
#
# * Excersises combine all the material for the midterm, but there's an indication of topic corresponding to each excersise
#
# * Feel free to share this notebook with other students, but please do not distribute it to the public (outside of university)
#
# * Remember to test your code for different outputs, add proper type hints and dosctrings to functions
#
# * Pay special attention to the 3 related student data excersises!
#
# * Good luck!

# %% [markdown]
# ### Level 1

# %% [markdown]
# #### Create a function that takes a name as input and capitalizes the first and fourth letters of the name.
#
# Rules:
#
# * If the name has at least four letters, the first and fourth letters will be capitalized.
# * If the name has fewer than four letters, the entire name will be capitalized.
# * Return the modified name as the output of the function.
#
# Examples:
#
# capitalize_name('macdonald') should return 'MacDonald'.
# capitalize_name('jo') should return 'JO'.
# capitalize_name('name') should return 'NamE'.

# %%
##your code here

# %% [markdown]
# **Write a function that computes the volume of a cube given its radius.**
#
# Topics: functions, arithmetics
#
# <p>The volume of a cube is given as $$a^3$$</p>

# %%
def volume():
    radius = int(input("radius:"))
    cube = radius**3
    return cube
    
volume()
# Out:
# radius: 2
# 8

# %% [markdown]
# #### ALMOST THERE: The passing grade for most of your courses is 5.5. Write a function that returns True if the grade is  within 0.2 lower than the passing grade.
#
# Topics: functions, artihmetics
#
# Example input: 5.4
#
# Output: True

# %%
## your code here

# %% [markdown]
# #### Now write the function that applies the function you just created to a list of grades and returns the number of grades that are within 0.2 lower than the passing grade, and the indexes of those grades. Then print an appropriate message
#
# Topics: lists, functions, arithmetics, calling functions
#
# Example input: [6.0, 5.5., 5.3, 5.4]
#
# Output: "2 grades in the ALMOST THERE range - at indexes [2, 3]"

# %% [markdown]
# ### Level 2

# %% [markdown]
# **Write a Python function that accepts a string and calculates the number of upper case, lower case letters, and spaces in a string.**
#
# Topics: functions, strings, arithmetics
#
# Example Input: 'Do not fear Python, unless it's not a snake'
#
# Output :
#     No. of Upper case characters : 2
#     No. of Lower case Characters : 31
#     No. of spaces: 8
#
# HINT: Two string methods that might prove useful: **.isupper()** and **.islower()**

# %%
##your code here

# %% [markdown]
# #### Something special: Write a function that takes in a list of strings and returns a list of unique strings
#
# Topics: lists, functions, loops
#
# Example input: ["cat", "dog", "meow", "meow"]
# Output: ["cat", "dog", "meow"]

# %%
## your code here

# %% [markdown]
# ##### BLACKJACK: Write a function generates 3 random integers between 1 and 11. If their sum is less than or equal to 21, return their sum. If their sum exceeds 21 *and* one of the integers is an 11, reduce the total sum by 10. Finally, if the sum (even after adjustment) exceeds 21, return 'BUST'. Print out (within the function) the integers and the resulting outcome
#
# Example: blackjack()
#
# Output: "Integers are: 1, 5, 9. SUM: 15."

# %%
## your code

# %% [markdown]
# #### Linguistics: Write a function that checks if a string is a palindrome or not
#
# A palindrome reads the same backward as forward, e.g., kayak or "nurses run". Do not take into account spaces or capital letters.
#
# Example input: kayak
#
# Output: True

# %%
## your code

# %% [markdown]
# #### Prime numbers: Write a function that takes in a number and returns a list of all prime numbers up to that number and their sum
#
# Example input: 5
#
# Output: [2,3], 5
#
# Note: 0 and 1 are by convention not considered prime!

# %%
## your code

# %% [markdown]
# ### The next 3 excersises are related to each other, please pay special attention to them!

# %% [markdown]
# #### Student data
#
# You are given a dictionary that contains information about students. Each student is represented by a unique ID, and their information is stored as a dictionary within the main dictionary. The student dictionaries contain the following keys: "name," "age," and "grade."
#
# Write a Python function that, given a student's ID, retrieves and returns the information for that student. If the ID is not found in the dictionary, the function should return a message indicating that the student does not exist.
#
# Example student data : {
#     101: {"name": "Alice", "age": 18, "grade": "A"},
#     102: {"name": "Bob", "age": 19, "grade": "B"},
#     103: {"name": "Charlie", "age": 20, "grade": "A"},
#     104: {"name": "David", "age": 18, "grade": "C"},
# }
#
# Example input: 102
# Output: {"name": "Bob", "age": 19, "grade": "B"}

# %%
# your code here

# %% [markdown]
# #### Student grades
#
# You are given a dictionary where each key represents a student's name, and the corresponding value is another dictionary containing the student's subject scores. Your task is to write a Python function that calculates the average score for each student and returns a new dictionary where the keys are the student names, and the values are their average scores.
#
# Write a function calculate_average_scores, that takes the student_scores dictionary as input and returns a new dictionary with student names as keys and their average scores as values.
#
#
# Example grades: student_scores = {
#     "Alice": {"Math": 85, "English": 92, "History": 78},
#     "Bob": {"Math": 90, "English": 88, "History": 85},
#     "Charlie": {"Math": 78, "English": 86, "History": 89},
#     "David": {"Math": 92, "English": 95, "History": 87},
# }
#
# Example output:
# {
#     "Alice": 85.0,
#     "Bob": 87.67,
#     "Charlie": 84.33,
#     "David": 91.33,
# }

# %% [markdown]
# ### Level 3

# %% [markdown]
# #### Top of the class
#
# You are given a list of dictionaries where each dictionary represents information about a person. The dictionaries have the following keys: "name", "age", and "score". Your task is to write a Python function that finds the top N people with the highest scores from the list. Your function should return a list of dictionaries containing the information of the top N people.
#
# Write a function top_n_people, that takes the list people and an integer N as input and returns a list of dictionaries containing the information of the top N people based on their scores.
#
# Example input:
#
#  [
#     {"name": "Alice", "age": 30, "score": 95},
#     {"name": "Bob", "age": 25, "score": 89},
#     {"name": "Charlie", "age": 35, "score": 92},
#     {"name": "David", "age": 28, "score": 98},
#     {"name": "Eve", "age": 27, "score": 85},
# ]
#
# Output:
# [
#     {"name": "David", "age": 28, "score": 98},
#     {"name": "Alice", "age": 30, "score": 95},
#     {"name": "Charlie", "age": 35, "score": 92}
# ]

# %%
## your code

# %% [markdown]
# #### All student data!!
#
# Using the functions in the previous 3 excersises create a function that takes in student data as a dictionary (like in the task Student Data), but WITHOUT their grade. Instead, the function also takes in the student_scores dictionary and computes the average grade based on those (you can call the previously created function). Then, add the average_grade to the student_data and retrieve the IDs of the top 3 students and their average score.
#
# Example input:
#
# student_data = {
#     101: {"name": "Alice", "age": 18},
#     102: {"name": "Bob", "age": 19},
#     103: {"name": "Charlie", "age": 20},
#     104: {"name": "David", "age": 18},
# }
#
# student_scores = {student_scores = {
#     "Alice": {"Math": 85, "English": 92, "History": 78},
#     "Bob": {"Math": 90, "English": 88, "History": 85},
#     "Charlie": {"Math": 78, "English": 86, "History": 89},
#     "David": {"Math": 92, "English": 95, "History": 87},
# }
#
# Output:
# updated dictionary:
# {
#     101: {"name": "Alice", "age": 18, "score": 85.0},
#     102: {"name": "Bob", "age": 19, "score": 87.67},
#     103: {"name": "Charlie", "age": 20, "score": 84.33},
#     104: {"name": "David", "age": 18, "score": 91.33},
# }
#
# top students:
# {104: 91.33, 102: 87.67, 101: 85.0}
#
# top students average: 88.0
#
# Note: how you decide to present/return the output is up to you!

# %%
## your code

# %% [markdown]
# #### Mushrooms
#
# You are given a dataset containing information about different types of mushrooms. Each mushroom is represented by a dictionary with attributes such as "color," "size," "odor," and "edibility." The attributes are stored as lists.
#
# Write a Python function that classifies mushrooms into two categories: "edible" and "poisonous." Additionally, the function should give mushrooms a name based on their first colour, size, and odor. Return a dictionary with the name of the mushroom as a key and their edibility as a value
#
# mushrooms = [
#     {
#         "color": ["red", "yellow"],
#         "size": ["small", "large"],
#         "odor": ["pungent", "spicy"],
#         "edibility": "poisonous",
#     },
#     {
#         "color": ["white", "brown"],
#         "size": ["medium", "small"],
#         "odor": ["anise", "none"],
#         "edibility": "edible",
#     }]
#
#   Output:
#
#   {
#       "red-small-pungent mushroom": "poisonous",
#       "white-medium-anise mushroom": "edible"
#    }

# %%
## your code

# %% [markdown]
# #### Wild cats
#
# You are working with a dataset of information about various species of wild cats in a conservation program. Each species is represented as a dictionary with attributes like "name," "population," and "habitat," and there is a nested dictionary with details about their diet, including the types of prey they hunt and their hunting success rates.
#
# Write a Python function wild_cat_stats that performs the following tasks:
#
# * Calculate the total population of all wild cat species.
# * Identify the species with the highest hunting success rate.
# * Determine the most common prey type among all the species.
#
# Example input:
#
# wild_cats = [
#     {
#         "name": "African Lion",
#         "population": 25000,
#         "habitat": "Savannah",
#         "diet": {
#             "prey_types": ["zebra", "wildebeest", "buffalo"],
#             "success_rate": 0.85,
#         },
#     },
#     {
#         "name": "Snow Leopard",
#         "population": 4000,
#         "habitat": "Mountainous regions",
#         "diet": {
#             "prey_types": ["ibex", "blue sheep", "marmots"],
#             "success_rate": 0.70,
#         },
#     },
# ]
#
# Output:
# {
#     "total_population": 29000,
#     "species_with_highest_success_rate": "African Lion",
#     "most_common_prey_type": "zebra",
# }
