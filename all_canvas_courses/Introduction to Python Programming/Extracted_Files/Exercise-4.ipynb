# %% [markdown]
# # Introduction to Python (# XB_0082) - Exercise 4 (2024-2025)
#
# ### Welcome to the course Intro to Python!
#
# The fourth Exercise helps you practice Dictionaries. It builds on what you've learnt last week!

# %% [markdown]
# ## Table of Contents
# * [First Things First](#first)
# * [Important Reminder](#reminder)
# * [Preliminaries](#preliminaries)
# * [1. Inventory](#exercise1)
# * [2. Game Sales](#exercise2)
# * [3. Collector's Club](#exercise3)
# * [4. Children's Games](#exercise4)
# * [5. Ingredients](#exercise5)
# * [6. Character Heights](#exercise6)

# %% [markdown]
# ## First Things First <a class="anchor" id="first"></a>
#
# Add your name and student number in the next cell as strings stored in the `AUTHOR_NAME` and `STUDENT_NUMBER` variables.
#
# Please note that throughout the Exercises and Assignments, the commented lines containing `BEGIN_TODO` and `END_TODO` will mark where you need to start and finish writing your code. **ALWAYS WRITE YOUR SOLUTIONS WITHIN THESE MARKS** as code outside of them might not be graded!
#
# An example of what you could have in the next cell looks like this:
#
# ```python
# #// BEGIN_TODO [author] First Things First`
#
# AUTHOR_NAME = 'John Doe'
# STUDENT_NUMBER = '1234567'
#
# #// END_TODO [author] First Things First`
# ```

# %%
#// BEGIN_TODO [author]

AUTHOR_NAME = ''    
STUDENT_NUMBER = ''

#// END_TODO [author]

# %% [markdown]
# ## Important Reminder <a class="anchor" id="reminder"></a>
#
# * Before jumping into coding, please note that you **NEED TO** follow all coding conventions defined on the Python Coding Standard document available via Canvas. Remember that you are not just programming for a *machine*, you are mainly programming for *other humans*!
#
#     * In particular, all variable declarations and function definitions must have **type hints**, and the latter a **docstring** as well.
#
#     * A *valid* docstring starts with a capital letter and ends with a dot.
#
# * Please also pay attention to the naming of your variables and the formatting of your output. The variable names and the output should match **exactly** with the examples given in each of the task descriptions to ensure that CodeGrade is able to grade your solution correctly.

# %% [markdown]
# ## Preliminaries <a class="anchor" id="preliminaries"></a>
#
# Run the cell below. This cell will import additional modules providing additional Python functionality.

# %%
# The lines starting with ! contain shell commands which install the extension Nb Mypy and its dependencies.
# Nb Mypy is a Jupyter extension which helps you automatically check type hinting in your notebooks.
# You only need to install these once: if you already did it (e.g., in the first Exercise notebook),
# then feel free to leave the two lines below commented.

#! python3 -m pip install mypy astor
# ! python3 -m pip install nb_mypy

# This line loads the Nb Mypy extension in this notebook.
# %load_ext nb_mypy
# Out:
# The nb_mypy extension is already loaded. To reload it, use:
#   %reload_ext nb_mypy

# %%
from typing import List, Dict, Any, Union

# %% [markdown]
# ## 1. Inventory <a class="anchor" id="exercise1"></a>
#
# A videogame store is creating an inventory of the games left over from a sale the week before. In this exercise, you will create a function called `create_inventory()` which helps with this task. As parameters, it should take the number of copies left over from adventure and sport games (called `adventure` and `sport`). It should return a dictionary named `inventory` which stores these numbers as values under the keys `adventure_copies` and `sport_copies`, respectively.
#
# *Notes:*
# * The function `create_inventory` is called when producing the printed output as shown in the example. That part of the code is already written for you **outside** of the `TODO` area, so do *not* modify that part. Your function does not need to print anything.
# * Pay attention to proper type hinting and creating a docstring.
#
# **Example:**
#
# *Input:*
# ```python
# adventure: int = 28
# sport: int = 44
# ```
#
# *Output:*
# <pre>
# COPIES LEFT OVER:
# Adventure: 28
# Sport: 44
# </pre>

# %%
adventure: int = 28
sport: int = 44

#// BEGIN_TODO [inventory] Inventory


#// END_TODO [inventory]

inventory = create_inventory(adventure, sport)

print('COPIES LEFT OVER:')
print(f'Adventure: {inventory["adventure_copies"]}')
print(f'Sport: {inventory["sport_copies"]}')
# Out:
# COPIES LEFT OVER:
# Adventure: 28
# Sport: 44

# %% [markdown]
# ## 2. Game Sales <a class="anchor" id="exercise2"></a>
#
# The same game store has also implemented a Python dictionary to keep track of the copies which they *have* sold of different game genres during the sale. In this exercise, create a function named `calculate_sales()` which takes such a dictionary as parameter (called `sales`) and calculates the total number of copies sold from adventure and sport games altogether. It should store this number in a local variable called `adventure_sport_sales` and output it in a printed message as shown in the example. It should not return anything.
#
# Call your function in the correct way using the given input to produce an output as shown below.
#
# **Example:**
#
# *Input:*
# ```python
# sales: Dict[str, int] = {'adventure_copies' : 139, 'platform_copies' : 88, \
#      'sport_copies' : 172, 'MOBA_copies' : 272}
# ```
#
# *Output:*
# <pre>
# Total copies sold from adventure and sport games: 311
# </pre>

# %%
sales: Dict[str, int] = {'adventure_copies' : 139, 'platform_copies' : 88, \
    'sport_copies' : 172, 'MOBA_copies' : 272} 

#// BEGIN_TODO [game_sales] Game Sales



#// END_TODO [game_sales]
# Out:
# Total copies sold from adventure and sport games: 311

# %% [markdown]
# ## 3. Collector's Club <a class="anchor" id="exercise3"></a>
#
# In this exercise, you will see some lines of code, but their order has been scrambled. Your job is to reconstruct the code by **ONLY PUTTING THE LINES IN THE CORRECT ORDER** and **NOT MODIFYING THEM**. You are not allowed to add or omit any lines of code, but you are of course allowed to add indentation.
#
# This particular program simulates the Collector's Club platform of the video game store from the previous exercises. The Collector's Club is an online platform, where video game collectors can open an account and keep track of the games they have purchased so far. For each game they store in their collection, they can save the publishing year and game studio.
#
# The program shown below contains a function named `new_game_entry()`, which takes as parameter a nested dictionary storing the collection of a user (collector) so far. In this nested dictionary, in the outer dictionary, the keys are game titles, and the values are the inner dictionaries. In the inner dictionaries, the keys are `'year'` and `'studio'`, and the values store the corresponding information about each of the game titles.
#
# When the function `new_game_entry()` is called, it lets the collector enter through user input the title of a newly purchased game they would like to store in their collection, as well as its publishing year and game studio. The function adds the new game to the collection dictionary it has taken as parameter and returns the updated dictionary.
#
# The program shown to you uses the output of this function (the updated dictionary) to print all the titles in a user's collection AFTER updating it with a new entry.
#
# *Note:* notice that while the function takes the collection dictionary (before the update) as a parameter, the new game entry is given by calling the `input()` function.
#
# **Example:**
#
# *Input:*
# ```python
# collection: Dict[str, Dict[str, any]] = {'The Last of Us' : {'year' : 2013, 'studio' : 'Naughty Dog'}, \
#     'God of War Ragnarok' : {'year' : 2022, 'studio' : 'Santa Monica Studio'}}
# ```
#
# <pre>
# Title of new game: Hogwarts Legacy
# Year of new game: 2023
# Studio of new game: Avalanche Software
# </pre>
#
# *Output:*
# <pre>
# CURRENT COLLECTION:
# The Last of Us, 2013 (Naughty Dog)
# God of War Ragnarok, 2022 (Santa Monica Studio)
# Hogwarts Legacy, 2023 (Avalanche Software)
# </pre>
#
# The scrambled lines are given below. Do not worry if it seems a bit complex at first glance - these lines of code might be a little more advanced than what you have already tried doing on your own. You will get there soon though! In the meantime, use what you already know about Python to decide in which order the lines must come, and recreate the original code in the cell below.
#
# ```python
# new_title: str = input('Title of new game: ')
#
# collection[new_title] = {'year' : new_year, 'studio' : new_studio}
#
# print('CURRENT COLLECTION:')
#
# studio = info['studio']
#
# '''Updates a game collection with a new entry through user input.
#     :param: collection: the collection before the update.
#     :return: a dictionary containing the updated collection.
#     '''
#
# new_studio: str = input('Studio of new game: ')
#
# updated_collection = new_game_entry(collection)
#
# year = info['year']
#
# def new_game_entry(collection:Dict[str,Dict[str,Any]]) -> Dict[str,Dict[str,Any]]:
#
# new_year: int = int(input('Year of new game: '))
#
# return collection
#
# for game, info in updated_collection.items():
#
# print(f'{game}, {year} ({studio})')
# ```

# %%
collection: Dict[str, Dict[str, Any]] = {'The Last of Us' : {'year' : 2013, 'studio' : 'Naughty Dog'}, \
    'God of War Ragnarok' : {'year' : 2022, 'studio' : 'Santa Monica Studio'}}

#// BEGIN_TODO [collectors_club] Collector's Club



#// END_TODO [collectors_club]
# Out:
# CURRENT COLLECTION:
# The Last of Us, 2013 (Naughty Dog)
# God of War Ragnarok, 2022 (Santa Monica Studio)
# COD, 2024 (Ubisoft)

# %% [markdown]
# ## 4. Children's Games <a class="anchor" id="exercise5"></a>
#
# A video game studio is contemplating to expand their business into games specifically designed for children. For this purpose, they have conducted a survey with the cooperation of a video game store, where they asked parents which popular kids' tales they would like to see adapted into a game. The result of this survey is stored in a Python dictionary named survey_results before the TODO section.
#
# In this dictionary, the keys are titles of children's tales, and the values are proportions representing the fraction of parents who would welcome a game from that tale. For instance, if you see the value `0.85` under the title `Winnie the Pooh`, that means that 85% of parents would be happy to see a Winnie-the-Pooh-themed game. (Since one parent might be happy to see games adapted from different tales, it is alright if the values in the dictionary do not add up to 100%.)
#
# Implement a Python function named `game_adaptations()` which takes as parameter a dictionary (called `survey_results`) containing such survey results as well as a threshold number and returns a list of tales which **exceed** the specified threshold that parents would like to see adapted into games. The function should not print anything, but your program should call the function in the correct way to produce a printed output as shown in the example.
#
# Example:
#
# *Input:*
# ```python
# survey_results: Dict[str, float] = {'Winnie the Pooh' : 0.85, 'Paw Patrol' : 0.65, 'Jungle Book' : 0.79, 'Hello Kitty' : 0.58}
# threshold: float = 0.75
# ```
#
# *Output:*
# <pre>
# Game adaptations above 75% popularity:
# Winnie the Pooh
# Jungle Book
# </pre>

# %%
survey_results: Dict[str, float] = {'Winnie the Pooh' : 0.85, 'Paw Patrol' : 0.65, 'Jungle Book' : 0.79, 'Hello Kitty' : 0.58}
threshold: float = 0.75

#// BEGIN_TODO [childrens_games] Children's Games

def game_adaptations(survey_results:Dict[str,float], threshold:float) -> List[str]:


#// END_TODO  [childrens_games]
# Out:
# Game adaptations above 75% popularity:
# Winnie the Pooh
# Jungle Book

# %% [markdown]
# ## 5. Ingredients <a class="anchor" id="exercise6"></a>
#
# In this exercise, your task will be to create a function called `all_ingredients()`, which helps a chef see all the different unique ingredients which they can order from any of their suppliers. For this purpose, the function should take as parameter a list of lists (called `suppliers`), where each inner list contains the ingredients supplied by a given supplier. It should return a list of all the unique ingredients offered by any supplier and print nothing.
#
# Importantly, your program should not print the names of all the unique ingredients but only their number by calling `all_ingredients()` in the correct way using the input. See the example below on how the program should work.
#
# *Hint:* pay attention that `all_ingredients()` does **not** return the *number* of unique ingredients, but a list of them. Their number is calculated *outside* of the function definition.
#
# *Note:* pay attention to correct type-hinting and docstring.
#
# #### 🔥 Python `not in` Operator 🔥
#
# The `not in` operator checks if an element is **not present** in a list, string, or any collection in Python. If the element is missing, it returns `True`; if it’s there, it returns `False`.
#
# ##### 💡 How to Use:
#
# ```python
# # Example: Checking if an item is NOT in a list
# fruits = ["apple", "banana", "cherry"]
#
# # Check if "grape" is NOT in the list
# if "grape" not in fruits:
#     print("Grape is not in the list!")
# ```
#
# Example:
#
# *Input:*
# ```python
# suppliers: List[List[str]] = [
#     ["Tomatoes", "Onions", "Garlic"],
#     ["Potatoes", "Carrots", "Onions", "Celery"],
#     ["Garlic", "Onions", "Mushrooms"],
#     ["Lettuce", "Tomatoes", "Cucumbers"],
# ]
# ```
#
# *Output:*
#
# <pre>
# The total number of unique ingredients is 9.
# </pre>

# %%
suppliers: List[List[str]] = [
    ["Tomatoes", "Onions", "Garlic"],
    ["Potatoes", "Carrots", "Onions", "Celery"],
    ["Garlic", "Onions", "Mushrooms"],
    ["Lettuce", "Tomatoes", "Cucumbers"],
]

#// BEGIN_TODO [ingredients] Ingredients

#// END_TODO  [ingredients]
# Out:
# The total number of unique ingredients is 9.

# %% [markdown]
# ## 6. Character Heights <a class="anchor" id="exercise6"></a>
#
# The video game store mentioned in the previous exercises does not only maintain a Collector's Club but also an online database of game characters. In this database, one property stored for each character is their height. For a blog post about this database, one of the store employees wants to find the height of some of the characters in the database.
#
# The problem is that the heights in the database are in the metric system, but the blog post is for a US audience, so that the values need to be converted into feet and inches. To solve this issue, create a function named `convert_heights()` which converts the heights of the characters in the database to the imperial system (feet and inches) and returns them stored in a new dictionary. It should work as follows:
#
# * One of its parameters should be a dictionary named `metric_heights`, where the keys are character names and the values are their heights given in centimeters.
#
# * The other parameter the function should take is a dictionary which contains the necessary information to convert centimeters to feet and inches (named `conversions`). Specifically, it contains two keys: `cm_to_inches` and `inches_in_a_foot`. Under the first key, you can find the conversion number from cm to inches, and under the second one, you can find the number of inches in a foot. The conversion must work as follows:
#     1. The height in centimeter must be converted to inches.
#     2. The inches must be converted to feet and inches (i.e., the number of whole feet + the remaining whole inches.)
#
#     An example for this: if the height was 175 cm, and 1 cm = 0.39 inches, then 175 cm = 68.25 inches. If there are 12 inches in a foot, then 68.25 inches is roughly 5 feet 8 inches.
#
# * The height in the imperial system must be converted to a string, so that for instance 5 feet 8 inches becomes `"5'8''"`.
#
# * This conversion should be done for all characters in the `metric_heights` database, and the results stored in a new dictionary named `imperial_heights`, where the keys are the character names and the values are the heights in the above specified string format. The function should return the dictionary `imperial_heights`.
#
# Please note that your function only needs to return this dictionary and not print anything. The output will be produced by the additional piece of code **outside** of the `TODO` area - your job is to create the function in the correct way so that the output of the complete cell below is as shown in the example.
#
# Example:
#
# *Input:*
# ```python
# metric_heights: Dict[str, int] = {'Super Mario' : 155, 'Lara Croft' : 170, 'Batman' : 188, 'Nathan Drake' : 180}
# conversions: Dict[str, Any] = {'cm_to_inches' : 0.39, 'inches_in_a_foot' : 12}
# ```
#
# *Output:*
#
# <pre>
# Character heights in the imperial system:
# Super Mario: 5'0''
# Lara Croft: 5'6''
# Batman: 6'1''
# Nathan Drake: 5'10''
# </pre>

# %%
metric_heights: Dict[str, int] = {'Super Mario' : 155, 'Lara Croft' : 170, 'Batman' : 188, 'Nathan Drake' : 180}
conversions: Dict[str, Any] = {'cm_to_inches' : 0.39, 'inches_in_a_foot' : 12}

#// BEGIN_TODO [character_heights] Character Heights



#// END_TODO  [character_heights]

imperial_heights = convert_heights(metric_heights, conversions)

print('Character heights in the imperial system:')

for character, height in imperial_heights.items():
    print(f'{character}: {height}')
# Out:
# Character heights in the imperial system:
# Super Mario: 5'0''
# Lara Croft: 5'6''
# Batman: 6'1''
# Nathan Drake: 5'10''

# %% [markdown]
# ## Congratulations!
# You have finished your fourth Intro to Python Exercise notebook.

# %% [markdown]
# ---
#
# # (End of Notebook)
#
# &copy; 2020-2025 - **TU/e** - **VU Amsterdam**
