# %% [markdown]
# # Introduction to Python (# XB_0082) - Exercise 1 (2024-2025)
#
# ### Welcome to the course Intro to Python!
#
# The Exercises aim to help you get hands-on experience with Python and practice before taking the Assignments.

# %% [markdown]
# ## Table of Contents
# * [First Things First](#first)
# * [Important Reminder](#reminder)
# * [Preliminaries](#preliminaries)
# * [0. Functions](#exercise0)
# * [1. A Simple Greeting](#exercise1)
# * [2. A Bit Less Simple Greeting](#exercise2)
# * [3. A Scrambled Greeting](#exercise3)
# * [4. A Buggy Greeting](#exercise4)
# * [5. Python Lines](#exercise5)
# * [6. Half Portion](#exercise6)
# * [7. Student Administration](#exercise7)

# %% [markdown]
# ## First Things First <a class="anchor" id="first"></a>
#
# Add your name and student number in the next cell as strings stored in the `AUTHOR_NAME` and `STUDENT_NUMBER` variables.
#
# Please note that throughout the Exercises and Assignments, the commented lines containing `BEGIN_TODO` and `END_TODO` will mark where you need to start and finish writing your code. **ALWAYS WRITE YOUR SOLUTIONS WITHIN THESE MARKS** as code outside of them might not be graded!
#
# An example of what you could have in the next cell looks like this:
#
# ```python
# #// BEGIN_TODO [author] First Things First`
#
# AUTHOR_NAME = 'John Doe'
# STUDENT_NUMBER = '1234567'
#
# #// END_TODO [author] First Things First`
# ```

# %%
#// BEGIN_TODO [author]

AUTHOR_NAME = ''
STUDENT_NUMBER = ''

#// END_TODO [author]

# %% [markdown]
# ## Important Reminder <a class="anchor" id="reminder"></a>
#
# * Before jumping into coding, please note that you **NEED TO** follow all coding conventions defined on the Python Coding Standard document available via Canvas. Remember that you are not just programming for a *machine*, you are mainly programming for *other humans*!
#
#     * In particular, all variable declarations and function definitions must have **type hints**, and the latter a **docstring** as well.
#
#     * A *valid* docstring starts with a capital letter and ends with a dot.
#
# * Please also pay attention to the naming of your variables and the formatting of your output. The variable names and the output should match **exactly** with the examples given in each of the task descriptions to ensure that CodeGrade is able to grade your solution correctly.

# %% [markdown]
# ## Preliminaries <a class="anchor" id="preliminaries"></a>
#
# Run the cells below. These cells will import additional modules providing additional Python functionality.

# %%
# The lines starting with ! contain shell commands which install the extension Nb Mypy and its dependencies.
# Nb Mypy is a Jupyter extension which helps you automatically check type hinting in your notebooks.
# After running it once, the packages are already installed on your computer, so feel free to comment these two lines.
# ! python3 -m pip install mypy astor
# ! python3 -m pip install nb_mypy

# This line loads the Nb Mypy extension in this notebook.
# %load_ext nb_mypy
# Out:
# Version 1.0.5

# %% [markdown]
# ## 0. Functions <a class="anchor" id="functions"></a>
#
# From this notebook on you will be expected to work functions. Here we provide some examples what your code should look like.
#
# For each task you are used to phrasing like this: "Write a **program** that takes as **input** an integer `x` and prints x + 1"
# This would look like this:
#
# ```python
# x: int = 5
#
# #// BEGIN_TODO [+1] +1
#
# #// END_TODO [+1]
# ```
#
# After solving:
# ```python
# x: int = 5
#
# #// BEGIN_TODO [+1] +1
#
# print(x + 1)
#
# #// END_TODO [+1]
# ```
#
# Now the language and the template change slightly.
#
# You can expect: "Write a **function** `plus1_print` that takes as **argument** an integer `x` and **prints** x + 1"
#
# This would look like:
# ```python
# #// BEGIN_TODO [+1] +1
#
# #// END_TODO [+1]
# ```
#
# Notice that we won't provide variables outside of the `todo` section anymore. Now let's look at it solved:
#
# ```python
# #// BEGIN_TODO [+1] +1
#
# def plus1_print(x: int) -> None:
#     print(x + 1)
#
# #// END_TODO [+1]
# ```
#
# In most cases you will be responsible for creating the function signature. Make sure you copy the given names **exactly**. For both the function and its arguments. You are also responsible for providing the correct typehints.
#
# Finally notice an important detail. So far we have been discussing printing some value, in most cases you will be asked to **return** something.
#
# You can expect: "Write a **function** `plus1` that takes as **argument** an integer `x` and **returns** x + 1"
#
# The final solution would look like:
#
# ```python
# #// BEGIN_TODO [+1] +1
#
# def plus1(x: int) -> int:
#     return x + 1
#
# #// END_TODO [+1]
# ```
#
# You can try out the code in the cell below

# %%
def plus1(x: int) -> int:
    return x + 1

def plus1_print(x: int) -> None:
    print(x + 1)

a = plus1(5)
b = plus1_print(1)

# What would their values be?
# print(a)
# print(b)

# %% [markdown]
# ### Testing your code
#
# Of course you want to test your code locally without going all the way to CodeGrade. We usually provide a single test but you can always add your own.
#
# **Do this outside the `TODO` tags**
#
# For example:

# %%
#// BEGIN_TODO [+1] +1

def plus1(x: int) -> int:
    return x + 1

#// END_TODO [+1]

# You can do what you want here
print(plus1(4)) # 5

# %% [markdown]
# ## 1. A Simple Greeting <a class="anchor" id="exercise1"></a>
#
# The first thing to do when starting to learn any programming language is to make a program that prints the message: **Hello world!**. This starting program is often very small and only uses some basic functionality of the programming language.
#
# Now, as your first experience with Python, write code using the `print()` function. The program, as expected, should print the message: 'Hello world!'. The quotes should not be in the output. They are used in the description of the exercises to indicate strings.
#
# **Notes:**
# - Remember that with Python you can either use single (`''`) or double quotes (`""`) to create strings.
# - Beware that capital and lowercase letters are treated different in Python. That is, 'L' is differently from 'l'.
#
# **Example:**
#
# *Input:*
# <pre>
# None
# </pre>
#
# *Output:*
# <pre>
# Hello world!
# </pre>

# %%
#// BEGIN_TODO [simple_greeting] A Simple Greeting

#// END_TODO [simple_greeting]
# Out:
# Hello world!

# %% [markdown]
# **Congratulations on your first Python program!**<br>
# Many more are bound to follow :-)

# %% [markdown]
# ## 2. A Bit Less Simple Greeting <a class="anchor" id="exercise2"></a>
#
# Printing messages as strings is a good way to output information on the screen, so you or others can read it. What is important is that messages printed this way can also be customized using values stored in variables.
#
# We will take our greeting one step further and print the following message: **Hi everyone, all the best wishes from given Name!**, where *Your Name* is substituted by a given name which you stored in  `name` variable.
#
# Your task is to create a program which prints such a message. Please pay attention to the remarks listed in *Notes* and study the provided example to see what your output should look like.
#
# **Notes**:
# - You are not allowed to use the `.format()` method.
# - Beware of upper and lowercase letters, as well of extra characters that have (not) been requested in the exercise (e.g. final '!' at the end of the message).
# - Note that while strings are denoted by quotation marks in Python (simple `'` or double `"`), these quotation marks do not show up in printed messages.
#
# **Example:**
#
# *Input:*
# ```python
# name = 'John Doe`
# ```
#
# *Output:*
# <pre>
# Hi everyone, all the best wishes from John Doe!
# </pre>

# %%
name = 'John Doe'

#// BEGIN_TODO [less_simple_greeting] A Bit Less Simple Greeting


#// END_TODO [less_simple_greeting]
# Out:
# Hi everyone, all the best wishes from John Doe!

# %% [markdown]
# ## 3. A Scrambled Greeting <a class="anchor" id="exercise3"></a>
#
# In this exercise, you will see some lines of code, but their order has been scrambled. Your job is to reconstruct the code by **ONLY PUTTING THE LINES IN THE CORRECT ORDER** and **NOT MODIFYING THEM**. You are not allowed to add or omit any lines of code.
#
# The code, before it was scrambled, could interact with the user. It used user input to ask for the user's full name, then used only the first name of the user as well as the first name of the author to print the message `Hi Firstname_user! I am Firstname_author, nice to meet you.`, where *Firstname_user* is the user's firstname, and *Firstname_author* is the first name extracted from the `AUTHOR_NAME` variable.
#
# Example of how the original code worked:
#
# Input:
# <pre>
# What is your full name? Jane Doe
# </pre>
#
# Output:
# <pre>
# Hi Jane! I am John, nice to meet you.
# </pre>
#
# The scrambled lines are given below. Do not worry if you are not familiar with every method used in these snippets - these lines of code are a bit more advanced than what you are required to create on your own at the moment. You will get there soon though! In the meantime, use what you already know about Python to decide in which order the lines must come, and recreate the original code in the cell below. If two variables positions in the code does not matter put them in alphabetic order in this task.
#
# ```python
# firstname_author: str = AUTHOR_NAME.split(' ')[0]
#
# firstname_user: str = fullname_user.split(' ')[0]
#
# print(message)
#
# message: str = 'Hi {user}! I am {author}, nice to meet you.'.format(user=firstname_user, author=firstname_author)
#
# fullname_user: str = input('What is your full name? ')
# ```

# %%
#// BEGIN_TODO [scrambled_greeting] A Scrambled Greeting


#// END_TODO [scrambled_greeting]
# Out:
# <cell>7: error: Name "AUTHOR_NAME" is not defined  [name-defined]
# Hi Mahbod! I am John, nice to meet you.

# %% [markdown]
# ## 4. A Buggy Greeting <a class="anchor" id="exercise4"></a>
#
# The code shown below prints a greeting to another student who has taken the course Intro to Python. It first asks this student's name, then in which year they took the Python course. Finally, it prints a message which includes the time difference between the time they took the course and when you are taking it (in 2023).
#
# An example of the working of this program is as follows:
#
# Input
# <pre>
# Hi other student! What is your name? Jane Doe
# In which year did you take the course Intro to Python? 2020
# </pre>
#
# Output
# <pre>
# Nice to meet you, Jane Doe! We have taken the Python course 3 years apart.
# </pre>
#
# The code for this program is shown below. However, this code is buggy: when you run it (by copying it into the next cell), it does not work properly. Your task is to find the mistake(s) in the code and correct them in the next cell. Please note that **you should also correct mistakes which allow the code to run** (e.g., think about proper type-hinting...).
#
# ```python
# student_name: str = input('Hi other student! What is your name? ')
#
# course_year: int = input('In which year did you take the course Intro to Python? ')
#
# years_difference: str = 2023 - course_year
#
# print('Nice to meet you, {student}! We have taken the Python course {difference} years apart.'.format(\
#     student_name, years_difference))
# ```

# %%
#// BEGIN_TODO [buggy_greeting] A Buggy Greeting



#// END_TODOD [buggy_greeting]
# Out:
# Nice to meet you, Alex! We have taken the Python course 1 years apart.

# %% [markdown]
# ## 5. Python Lines <a class="anchor" id="exercise5"></a>
#
# Let us assume that the number of lines of code a student writes grows linearly with each week of the Intro to Python course. So, for instance, if a student writes 42 lines of code in the first week and 52 lines of code in the second, then they will write 62 lines of code in the third week.
#
# In this exercise, your task is to write a simple program which takes as input two numbers representing the numbers of lines of code written in the first and second weeks of the course, and the output is a message containing the number of lines written in the third week.
#
# *Hint:* you can think of the numbers of lines of code written in each week as an arithmetic sequence (where the difference between consecutive terms is constant).
#
# Example:
#
# *Input*
#
# ```python
# lines_firstWeek: int = 42
# lines_secondWeek: int = 52
# ```
#
# *Output*
#
# <pre>
# This student wrote 62 lines of code in the 3rd week.
# </pre>

# %%
lines_firstWeek: int = 42
lines_secondWeek: int = 52

#// BEGIN_TODO [lines] Python Lines



#// END_TODO [lines]
# Out:
# This student wrote 62 lines of code in the 3rd week.

# %% [markdown]
# ## 6. Half Portion <a class="anchor" id="exercise1"></a>
#
# In a restaurant, you can ask for half a portion of a meal, but the price is then 60% of the original price (as ingredients are not the only expenses associated with cooking). In this task, create a Python function called `half_portion`, which takes as parameter the original price of a meal in Euros and prints the half-portion price.
#
# *Note:* the message should print the price rounded to 2 decimals.
#
# **Example:**
#
# *Input:*
# ```python
# original_price: float = 24.9
# ```
#
# *Output:*
# <pre>
# The half-portion price of this meal is 14.94.
# </pre>

# %%
original_price: float = 24.9

#// BEGIN_TODO [half_portion] Half Portion

#// END_TODO [half_portion]

half_portion(original_price)
# Out:
# A group of 2 students can be constructed in 1770 different ways.

# %% [markdown]
# ## 7. Student Administration <a class="anchor" id="exercise7"></a>
#
# In this exercise, you will devise a simple program which will help in some administrative tasks in a university.
#
# This program will take a student's first and last name as input as well as the number of courses they passed that year, and it will do four things:
# * it will print the student's full name,
# * it will generate the student's university email address, which is constructed as `firstname.lastname@student.uni.nl`,
# * it will print the percentage of courses the student passed that year rounded to one decimal (you can assume that each student registers for a total of 12 courses yearly),
# * and it will help print report cards by printing `PASS` in a single line as many times as the number of courses the student has passed.
#
# *Notes:*
# * Pay attention that email addresses can only have lowercase letters! Python has a built-in method for strings to change them to all lowercase, so you might want to look into this on the Internet.
# * This time, use the `format()` method when printing your output.
# * Do **not** use a for or while loop in your solution.
#
# Example:
#
# *Input:*
#
# ```python
# first_name: str = 'John'
# last_name: str = 'Doe'
# nr_passed: int = 10
# ```
#
# *Output:*
#
# <pre>
# Name: John Doe
# Email address: john.doe@student.uni.nl
# Percentage of courses passed: 83.3%
# Report card: PASS PASS PASS PASS PASS PASS PASS PASS PASS PASS
# </pre>

# %%
first_name: str = 'John'
last_name: str = 'Doe'
nr_passed: int = 10

#// BEGIN_TODO [administration] Student Administration



#// END_TODO [administration]
# Out:
# Name: John Doe
# Email address: john.doe@student.uni.nl
# Percentage of courses passed: 83.3%
# Report card: PASS PASS PASS PASS PASS PASS PASS PASS PASS PASS

# %% [markdown]
# ## Congratulations!
# You have finished your first Intro to Python Exercise notebook.

# %% [markdown]
# ---
#
# # (End of Notebook)
#
# &copy; 2020-2025 - **TU/e** - **VU Amsterdam**
