# %% [markdown]
# # Introduction to Python (# XB_0082) - Exercise 6 (2024-2025)
#
# The sixth Exercise helps you practice tests. It builds on what you've learnt the past few weeks!

# %% [markdown]
# ## Table of Contents
# * [First Things First](#first)
# * [Important Reminder](#reminder)
# * [Preliminaries](#preliminaries)
# * [1. Rectangle Area](#exercise1)
# * [2.1 New Art Pieces](#exercise2_1)
# * [2.2 Test New Art Pieces](#exercise2_2)
# * [3.1 Ticket Prices](#exercise3_1)
# * [3.2 Test Ticket Prices](#exercise3_2)

# %% [markdown]
# ## First Things First <a class="anchor" id="first"></a>
#
# Add your name and student number in the next cell as strings stored in the `AUTHOR_NAME` and `STUDENT_NUMBER` variables.
#
# Please note that throughout the Exercises and Assignments, the commented lines containing `BEGIN_TODO` and `END_TODO` will mark where you need to start and finish writing your code. **ALWAYS WRITE YOUR SOLUTIONS WITHIN THESE MARKS** as code outside of them might not be graded!
#
# An example of what you could have in the next cell looks like this:
#
# ```python
# #// BEGIN_TODO [author] First Things First`
#
# AUTHOR_NAME = 'John Doe'
# STUDENT_NUMBER = '1234567'
#
# #// END_TODO [author] First Things First`
# ```

# %%
#// BEGIN_TODO [author]

AUTHOR_NAME = ''
STUDENT_NUMBER = ''

#// END_TODO [author]

# %% [markdown]
# ## Important Reminder <a class="anchor" id="reminder"></a>
#
# * Before jumping into coding, please note that you **NEED TO** follow all coding conventions defined on the Python Coding Standard document available via Canvas. Remember that you are not just programming for a *machine*, you are mainly programming for *other humans*!
#
#     * In particular, all variable declarations and function definitions must have **type hints**, and the latter a **docstring** as well.
#
#     * A *valid* docstring starts with a capital letter and ends with a dot.
#
# * Please also pay attention to the naming of your variables and the formatting of your output. The variable names and the output should match **exactly** with the examples given in each of the task descriptions to ensure that CodeGrade is able to grade your solution correctly.

# %% [markdown]
# ## Preliminaries <a class="anchor" id="preliminaries"></a>
#
# Run the cell below. This cell will import additional modules providing additional Python functionality.

# %%
# The lines starting with ! contain shell commands which install the extension Nb Mypy and its dependencies.
# Nb Mypy is a Jupyter extension which helps you automatically check type hinting in your notebooks.
# You only need to install these once: if you already did it (e.g., in the first Exercise notebook),
# then feel free to leave the two lines below commented.

#! python3 -m pip install mypy astor
#! python3 -m pip install nb_mypy

# This line loads the Nb Mypy extension in this notebook.
# %load_ext nb_mypy

# %%
# !pip install pytest
from typing import List, Dict, Union, Tuple
import pytest

# %% [markdown]
# ## 1. Rectangle Area <a class="anchor" id="exercise1"></a>
#
# In this task you have to run multiple tests on the function `rectangle_area()`, which calculates the area of a rectangle based on its width and length and returns the area of the rectangle.
#
# This is the `rectangle_area()` function:
# ```python
# def rectangle_area(width: Union[int, float], height: Union[int, float]) -> Union[int, float]:
#     """
#     This function calculates the area of a rectangle by multiplying the width and the height.
#
#     :param width: An integer or a float value which is the width of the rectangle.
#     :param height: An integer or a float value which is the height of the rectangle.
#
#     :return: The area of the rectangle.
#     """
#     area = width * height
#     return area
# ```
#
# You have to implement these test functions:
# * `test_integer_multiplication()`, which checks if the rectangle area is calculated correctly when we have width = 6 and height = 4 (the rectangle_area should be equal to 24). If this fails, the function should give the message `"The rectangle area for width 6 and height 4 should be 24."`.
# * `test_float_integer_multiplication()`, which checks if the rectangle area is calculated correctly when we have width = 2.4 and height = 7 (the rectangle_area should be equal to 16.8). If this fails, the function should give the message `"The rectangle area for width 2.4 and height 7 should be 16.8."`
# * `test_float_multiplication()`, which checks if the rectangle area is calculated correctly when we have width = 2.5 and height = 3.5 (the rectangle_area should be equal to 8.75). If this fails, the function should give the message `"The rectangle area for width 2.5 and height 3.5 should be 8.75."`
# * `test_rectangle_area_unit_tests()`, which should call the functions: `test_integer_multiplication()`, `test_float_integer_multiplication()`, and `test_float_multiplication()`.
#
# *Notes*:
# * All test functions should not take any parameters and should not return anything.
# * The function `test_rectangle_area_unit_tests()` executes all the tests.
#
# *Input:*
# ```python
# rectangle_width: int = 8
# rectangle_height: int = 7
# ```
#
# *Output:*
# <pre>
# The rectangle has an area of 56 square meters.
# </pre>

# %%
rectangle_width: int = 8
rectangle_height: int = 7

#// BEGIN_TODO [rectangle_area] Rectangle Area

#// END_TODO [rectangle_area]

area = rectangle_area(rectangle_width, rectangle_height)
print(f'The rectangle has an area of {area} square meters.')

def test_rectangle_area_unit_tests() -> None:
    test_integer_multiplication()
    test_float_integer_multiplication()
    test_float_multiplication()

test_rectangle_area_unit_tests()

# %% [markdown]
# ## 2.1 New Art Pieces <a class="anchor" id="exercise2_1"></a>
#
# The curator of a museum wants to acquire new art pieces. Your task is to add the new art pieces to the collection. You need to write a function called `add_pieces_to_collection()` that takes two parameters: `current_collection`, which is the list of names of art pieces in the museum, and `new_art_pieces`, which represents the list of names of the new art pieces. The function should check each item in `new_art_pieces`, and if the piece is not in the current collection, it will add it to the current collection, but if the piece already exists, it must throw an Exception with the message `Error - The art piece X already exists in the collection.`. This function must return the updated collection.
#
# **Example:**
#
# *Input:*
# ```python
# art_collection: List[str] = ["Judith and the Head of Holofernes", "Guernica", "Broadway Boogie Woogie"]
# new_art: List[str] = ["The Temptation of St. Anthony", "Bird in Space"]
# ```
#
# *Output:*
# <pre>
# Your updated collection has the following art pieces:
# - Judith and the Head of Holofernes
# - Guernica
# - Broadway Boogie Woogie
# - The Temptation of St. Anthony
# - Bird in Space
# </pre>

# %%
art_collection: List[str] = ["Judith and the Head of Holofernes", "Guernica", "Broadway Boogie Woogie"]
new_art: List[str] = ["The Temptation of St. Anthony", "Bird in Space"]

#// BEGIN_TODO [new_art_pieces] New Art Pieces

#// END_TODO [new_art_pieces]

try:
    updated_collection = add_pieces_to_collection(art_collection, new_art)
    print("Your updated collection has the following art pieces:")
    
    for art_piece in updated_collection:
        print(f'- {art_piece}')

except Exception as duplicate_art_piece:
    print(duplicate_art_piece)

# %% [markdown]
# ## 2.2 Test New Art Pieces <a class="anchor" id="exercise2_2"></a>
#
# Now that you have implemented the function `add_pieces_to_collection()`, we will proceed to test such functionality:
# * `test_empty_art_collection()`, which should assert that if the function receives an empty new list of art pieces, the resulting list after executing the list should not change. For example, if the input collection of artworks was 5, after calling the function with an empty list of new art pieces, the result must be 5.
# * `test_empty_collection()`, should test that if the current museum collection is empty, and you add a new list of art pieces, the result contains the newly added art pieces.
# * `test_existing_art_piece()`, this test should guarantee that if the user tries to add an art piece that already exists in the collection, the function must raise an Exception.
#
# *Notes*:
# * All test functions should not take any parameters and should not return anything.
# * The function `test_add_pieces_to_collection()` executes all the tests.
# * You should use pytest for checking for exceptions.

# %%
#// BEGIN_TODO [test_add_pieces_to_collection] Test Add Piece To Collection

#// END_TODO [test_add_pieces_to_collection]

def test_add_pieces_to_collection() -> None:
    test_empty_art_collection()
    test_empty_collection()
    test_existing_art_piece()

test_add_pieces_to_collection()

# %% [markdown]
# ## 3.1 Ticket Prices <a class="anchor" id="exercise3_1"></a>
#
# The museum has different ticket prices for visitors of different age groups. Your task is to calculate the total ticket price for different groups of people. Write a function named `total_ticket_price()` that takes two parameters: `ticket_prices`, which represents a dictionary with ticket prices for each age group, and `visitors`, which is a list representing a group of visitors who want tickets (each visitor is represented by their age group; e.g., John is an adult, so he will be represented as 'Adult' in the list).
#
# The function has to:
# * Verify that the ticket price of each age group is above zero. If any ticket price is zero or negative, the function must throw a ValueError with the error message `Error - The ticket price for the age group X should be above zero.`
# * If the `visitors` list is empty it must raise an Exception with the error message `Error - No visitors in the visitor list.`.
# * Verify that the `visitors` list contains only string values. If any other value besides string values is found inside the list, the function should throw a TypeError with the error message `Error - Expected only string values in the visitor list.`.
# * Check if the age group of each visitor exists in the `ticket_prices` dictionary. If a visitor's age group does not exist in the `ticket_prices` dictionary, the function should throw an exception with the error message `Error - The age group X is not within the valid visitor types.`
# * After that, the function has to add each visitor's ticket price to the total ticket price.
# * Also, if the total price is a whole number (e.g., 10.0, 15.0, 19.0), its data type should be changed to an integer.
# * The function returns the ticket price as an integer or as a float.
#
# *Hint*:
# * In Python, 50 (int) and 50.0 (float) aren't truly identical; they’re just treated as equal because Python’s comparison operator converts the integer to a float (C double) for comparison. Since Python is implemented in C, this conversion aligns them in type, making 50 == 50.0 evaluate as True.
#
# **Example:**
#
# *Input:*
# ```python
# example_ticket_prices: Dict[str, float] = {'Child': 8.0, 'Adult': 15.00, 'Senior': 10.50}
# example_visitors: List[str] = ['Senior', 'Child', 'Senior', 'Adult']
# ```
#
# *Output:*
# <pre>
# The total ticket price for this group is 44 euros.
# </pre>

# %%
example_ticket_prices: Dict[str, float] = {'Child': 8.0, 'Adult': 15.00, 'Senior': 10.50}
example_visitors: List[str] = ['Senior', 'Child', 'Senior', 'Adult']

#// BEGIN_TODO [total_ticket_price] Total Ticket Price

#// END_TODO [total_ticket_price]

try:
    total_price = total_ticket_price(example_ticket_prices, example_visitors)
    print(f'The total ticket price for this group is {total_price} euros.')

except ValueError as negative_price:
    print(negative_price)

except TypeError as wrong_type:
    print(wrong_type)
    
except Exception as invalid_visitor:
    print(invalid_visitor)

# %% [markdown]
# ## 3.2 Test Ticket Prices <a class="anchor" id="exercise3_2"></a>
#
# To test the functionality of the `total_ticket_price()` function, the following test functions should be implemented:
# * `test_no_visitors()`, which guarantees that if there are no visitors, the `total_ticket_price()` function should throw an Exception with the message `Error - No visitors in the visitor list.`.
# * `test_other_data_types()`, which tests that if any non-string value is in the `visitors` list, the function throws a TypeError.
# * `test_return_type()`, should check that when the total ticket price is calculated with whole age group ticket prices (e.g., 12.0, 15.0), the result of the function is an integer.
# * `test_default()`, which tests the output of the function by asserting that the `total_ticket_price()` function returns the correct price when given `visitors = ['Child','Adult']`.
# * `test_order_visitors()`, which verifies that the order of the visitors in the list does not change the result.
# * `test_valid_visitor_type()`, this test guarantees that if there is a visitor in the `visitors` list that is not in the `ticket_prices`, the function must raise an Exception.
# * `test_greater_than_zero_price()`, this should confirm that if there is any negative or zero ticket price in the ticket prices dictionary, the function raises a ValueError.
#
# *Notes*:
# * All test functions should not take any parameters and should not return anything.
# * The function `test_total_ticket_price()` executes all test functions.
# * For the `test_other_data_types()`, make sure to include a variety of non-string values in the visitors list, such as integers (e.g., 0), floats (e.g., 7.8), and booleans (e.g., False). Try testing each of these values in separate cases to verify that all non-string values are handled correctly.
#
# *Hint*:
# * The valid visitor types can be found in the `ticket_prices` dictionary.

# %%
#// BEGIN_TODO [test_total_ticket_price] Test Total Ticket Price

#// END_TODO [test_total_ticket_price]

def test_total_ticket_price() -> None:
    test_no_visitors()
    test_other_data_types()
    test_return_type()
    test_default()
    test_order_visitors()
    test_valid_visitor_type()
    test_greater_than_zero_price()

test_total_ticket_price()

# %% [markdown]
# ## Congratulations!
# You have finished your sixth Intro to Python Exercise notebook.

# %% [markdown]
# ---
#
# # (End of Notebook)
#
# &copy; 2020-2025 - **TU/e** - **VU Amsterdam**
