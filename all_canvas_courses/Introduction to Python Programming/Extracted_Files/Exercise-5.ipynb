# %% [markdown]
# # Introduction to Python (# XB_0082) - Exercise 5 (2024-2025)
#
# The fifth Exercise helps you practice exceptions. It builds on what you've learnt the past few weeks!

# %% [markdown]
# ## Table of Contents
# * [First Things First](#first)
# * [Important Reminder](#reminder)
# * [Preliminaries](#preliminaries)
# * [Magic Potion Maker](#exercise1)
# * [Magical Number Finder](#exercise2)
# * [Advanced Magical Creature Encyclopedia](#exercise3)
# * [Treasure Chest Lock Puzzle](#exercise4)
# * [Advanced Potion Ingredient Management](#exercise5)
# * [Basketball Team Roster Management](#exercise6)

# %% [markdown]
# ## First Things First <a class="anchor" id="first"></a>
#
# Add your name and student number in the next cell as strings stored in the `AUTHOR_NAME` and `STUDENT_NUMBER` variables.
#
# Please note that throughout the Exercises and Assignments, the commented lines containing `BEGIN_TODO` and `END_TODO` will mark where you need to start and finish writing your code. **ALWAYS WRITE YOUR SOLUTIONS WITHIN THESE MARKS** as code outside of them might not be graded!
#
# An example of what you could have in the next cell looks like this:
#
# ```python
# #// BEGIN_TODO [author] First Things First`
#
# AUTHOR_NAME = 'John Doe'
# STUDENT_NUMBER = '1234567'
#
# #// END_TODO [author] First Things First`
# ```

# %%
#// BEGIN_TODO [author]

AUTHOR_NAME = ''
STUDENT_NUMBER = ''

#// END_TODO [author]

# %% [markdown]
# ## Important Reminder <a class="anchor" id="reminder"></a>
#
# * Before jumping into coding, please note that you **NEED TO** follow all coding conventions defined on the Python Coding Standard document available via Canvas. Remember that you are not just programming for a *machine*, you are mainly programming for *other humans*!
#
#     * In particular, all variable declarations and function definitions must have **type hints**, and the latter a **docstring** as well.
#
#     * A *valid* docstring starts with a capital letter and ends with a dot.
#
# * Please also pay attention to the naming of your variables and the formatting of your output. The variable names and the output should match **exactly** with the examples given in each of the task descriptions to ensure that CodeGrade is able to grade your solution correctly.

# %% [markdown]
# ## Preliminaries <a class="anchor" id="preliminaries"></a>
#
# Run the cell below. This cell will import additional modules providing additional Python functionality.

# %%
# The lines starting with ! contain shell commands which install the extension Nb Mypy and its dependencies.
# Nb Mypy is a Jupyter extension which helps you automatically check type hinting in your notebooks.
# You only need to install these once: if you already did it (e.g., in the first Exercise notebook),
# then feel free to leave the two lines below commented.

#! python3 -m pip install mypy astor
#! python3 -m pip install nb_mypy

# This line loads the Nb Mypy extension in this notebook.
# %load_ext nb_mypy
# Out:
# Version 1.0.5

# %%
from typing import List, Dict, Any, Union

# %% [markdown]
# ## 1. Magic Potion Maker <a class="anchor" id="exercise1"></a>
# You are an apprentice potion maker working in a mystical shop. Your master has asked you to create a function named `make_potion()` that helps customers brew the perfect magic potion. As parameters, it should take the `strength`. The stronger the potion, the more powerful its effect!
#
# Your task is to prompt the user to input a potion strength:
#
# *Notes:*
# * If the number is out of range (less than 1 or greater than 5), raise a ValueError and display: "Potion strength must be between 1 and 5."
# * If the input is valid, print a message indicating the potion is successfully brewed.
# * Use a try-except block to handle cases where the input is not a valid number or out of range.
#
# **Example:**
#
# *Input1:*
# ```python
# strength :int = 8
# ```
# *Input2:*
# ```python
# strength :int = 5
# ```
# *Output1:*
# <pre>
# Potion strength must be between 1 and 5.
# </pre>
#
# *Output2:*
# <pre>
# Potion strength 5! Your potion is ready and bubbling!
# <pre>

# %%
strength :int =5
#// BEGIN_TODO [Magic Potion Maker]

#// END_TODO [Magic Potion Maker]
try:
    make_potion(strength)
except ValueError:
        print("Potion strength must be between 1 and 5.")
# Out:
# Potion strength 5! Your potion is ready and bubbling!

# %% [markdown]
# ## 2. Magical Number Finder <a class="anchor" id="exercise1"></a>
# You are a novice wizard studying magical numbers. Your mentor has asked you to create a function named `find_magic_number()` that helps identify if a given number exists in a list of magical numbers. This function takes as parameters a list of magical numbers (`magical_numbers`) and a number (`number`), and returns a message indicating if the number received as parameter is magic.
#
# Your task is to check if a predefined number exists in the provided list of magical numbers:
#
# *Notes:*
# * The function should take a list of `magical_numbers` and `number` to check as parameters.
# * If the number is not an integer, raise a ValueError containing the message: "Invalid input! Please enter a valid number."
# * If the number exists in the list, return a message indicating that the number is magical.
# * If the number does not exist in the list, return a message indicating that the number is not magical.
#
# **Example:**
#
# *Input1:*
# ```python
# magical_numbers = [3, 7, 11, 42]
# number = "ten"
# ```
# *Input2:*
# ```python
# magical_numbers = [3, 7, 11, 42]
# number = 3
# ```
# *Input3:*
# ```python
# magical_numbers = [3, 7, 11, 42]
# number = 10
# ```
# *Output1:*
# <pre>
# Invalid input! Please enter a valid number.
# </pre>
#
# *Output2:*
# <pre>
# The number 3 is magical!
# </pre>
#
# *Output3:*
# <pre>
# The number 10 is not magical.
# </pre>

# %%
magical_numbers : List[int] = [3, 7, 11, 42]
number:int = "ten"
#// BEGIN_TODO [Magical Number Finder]

#// END_TODO [Magical Number Finder]
try:
    find_magic_number(magical_numbers, number)
except ValueError as exception:      
    print(exception)
# Out:
# <cell>2: error: Incompatible types in assignment (expression has type "str", variable has type "int")  [assignment]
# Invalid input! Please enter a valid number.

# %% [markdown]
# ## 3. Advanced Magical Creature Encyclopedia <a class="anchor" id="exercise1"></a>
# You are an aspiring magical creature expert working on an advanced encyclopedia for magical creatures. Your mentor has tasked you with creating a function named `update_creature_info()` that allows users to retrieve or update information about magical creatures in a dictionary.
#
# Your task is to implement the following functionality:
#
# * If a valid creature name is provided, return its information.
# * If the user provides a valid creature name and new information, update the information for that creature.
#
# Use exceptions to handle the following case:
# * If the creature name is empty, raise a ValueError and display: "Creature name cannot be empty."
#
# *Notes:*
#
# * The function should take three parameters: a dictionary `magical_creatures`, `creature_name` as a string, and an optional string parameter `information`.
# * The function should print appropriate messages based on whether the action is retrieving or updating information.
#
# **Example:**
#
# *Input1:*
# ```python
# magical_creatures = {
#     "Unicorn": "A magical horse with a horn.",
#     "Dragon": "A large, fire-breathing creature.",
#     "Phoenix": "A bird that is reborn from its ashes."
# }
# creature_name = "Dragon"
# ```
# *Input2:*
# ```python
# magical_creatures = {
#     "Unicorn": "A magical horse with a horn.",
#     "Dragon": "A large, fire-breathing creature.",
#     "Phoenix": "A bird that is reborn from its ashes."
# }
# creature_name = "Phoenix"
# information = "A mythical bird that rises from its ashes in flames."
# ```
# *Input3:*
# ```python
# magical_creatures = {
#     "Unicorn": "A magical horse with a horn.",
#     "Dragon": "A large, fire-breathing creature.",
#     "Phoenix": "A bird that is reborn from its ashes."
# }
#
# creature_name = ""
# ```
# *Output1:*
# <pre>
# A large, fire-breathing creature.
# </pre>
#
# *Output2:*
# <pre>
# The information for Phoenix has been updated.
# </pre>
#
# *Output3:*
# <pre>
# Creature name cannot be empty.
# </pre>

# %%
magical_creatures: Dict[str,str] = {
    "Unicorn": "A magical horse with a horn.",
    "Dragon": "A large, fire-breathing creature.",
    "Phoenix": "A bird that is reborn from its ashes."
}

creature_name: str = "Dragon"

#// BEGIN_TODO [Advanced Magical Creature Encyclopedia]

#// END_TODO [Advanced Magical Creature Encyclopedia]
try:
    update_creature_info(magical_creatures,creature_name)
except ValueError:
        print("Creature name cannot be empty.")
# Out:
# The information for Dragon has been updated.

# %% [markdown]
# ## 4. Treasure Chest Lock Puzzle <a class="anchor" id="exercise1"></a>
# You are an adventurer trying to unlock a magical treasure chest. The chest is protected by a series of number locks, and each lock has a specific number code. You have a list of codes to try, but some codes may not work because the lock requires only positive integers.
#
# Your task is to create a function named `unlock_chest()` that takes a list of integers `codes` and attempts to unlock each lock by checking its code. The function should:
#
# * If the list of codes is empty, it should raise an Exception with the message: `The list of codes cannot be empty.`
# * Iterate through the list of codes.
# * For each code it should check if the code is not positive , raise a ValueError and display an error message `Invalid code: {code} must be a positive integer.`
# * If all the codes are valid it should return a message saying: "All locks successfully unlocked!"
#
# *Notes:*
#
# * Use a try-except block to handle invalid codes.
#
#
# **Example:**
#
# *Input:*
# ```python
# codes = [123, 456, -789, 0, 987]
# ```
# *Output:*
# <pre>
# Invalid code: -789 must be a positive integer.
# Invalid code: 0 must be a positive integer.
# <pre>

# %%
codes: List[int] = [123, 456, -789, 0, 987]
#// BEGIN_TODO [Treasure Chest Lock Puzzle]


#// END_TODO [Treasure Chest Lock Puzzle]
try:
    unlock_chest(codes)
except ValueError as value_error:
    print(value_error)
except Exception as exception:
    print(exception)
# Out:
# Invalid code: -789 must be a positive integer.

# %% [markdown]
# ## 5. Advanced Potion Ingredient Management <a class="anchor" id="exercise1"></a>
# You are a master potion maker managing an advanced inventory system for your magical apothecary. Each ingredient has specific properties: name, quantity, and type (e.g., herb, mineral, essence).
#
# Your task is to create a function named `get_ingredient_info()` that takes as parameters a dictionary of `potion_ingredients` and an `ingredient_name`. The function should return information about the specified ingredient, including its quantity and type.
#
# Function Requirements:
# * If the ingredient exists, return a formatted string containing its quantity and type.
# * If the ingredient is not found, raise a KeyError with the message: "Ingredient not found!".
# * If the ingredient name provided is an empty string, raise a ValueError with the message "Invalid ingredient name!".
# * If the ingredient exists but the quantity is zero, return "Out of stock!".
#
# *Notes:*
# * Use a try-except block to handle errors.
#
# **Example:**
#
# *Input1:*
# ```python
# potion_ingredients = {
#     "Mandrake Root": {"quantity": 5, "type": "herb"},
#     "Dragon Scales": {"quantity": 0, "type": "mineral"},
#     "Phoenix Feather": {"quantity": 2, "type": "essence"}
# }
# ingredient_name = "Mandrake Root"
# ```
# *Input2:*
# ```python
# potion_ingredients = {
#     "Mandrake Root": {"quantity": 5, "type": "herb"},
#     "Dragon Scales": {"quantity": 0, "type": "mineral"},
#     "Phoenix Feather": {"quantity": 2, "type": "essence"}
# }
# ingredient_name = "Dragon Scales"
# ```
# *Output1:*
# <pre>
# Mandrake Root: 5 (herb)
# </pre>
# *Output2:*
# <pre>
# Out of stock!
# <pre>

# %%
potion_ingredients:Dict[str, Dict[str, Union[int, str]]] = {
    "Mandrake Root": {"quantity": 5, "type": "herb"},
    "Dragon Scales": {"quantity": 0, "type": "mineral"},
    "Phoenix Feather": {"quantity": 2, "type": "essence"}
}

ingredient_name:str = "Mandrake Root"
#// BEGIN_TODO [Advanced Potion Ingredient Management]

#// END_TODO [Advanced Potion Ingredient Management]
try:
    get_ingredient_info(potion_ingredients, ingredient_name)
except ValueError as invalid_name:
    print(invalid_name)
except KeyError as ingredient_not_found:
    print(ingredient_not_found)

# %% [markdown]
# ## 6. Basketball Team Roster Management  <a class="anchor" id="exercise1"></a>
# You are the manager of a basketball team and need to keep track of your players, their statistics, and their positions. Each player has the following information: name (string), position (string), points Scored (integer), games played (integer).
#
# You need to create a function named `update_player_stats()` that allows you to update the stats for a player based on their name. If the player is not found, an exception should be raised.
#
# The function should accept a dictionary `players`, where the keys are player names and the values are dictionaries containing their statistics. The function should also accept a string `player_name`, a new variable for points called `points_scored`, and a new variable for games called `games_played`.
#
# *Notes:*
# * If the player exists, update their points and games played.
# * If the player does not exist, raise a KeyError with the message: "Player not found!".
# * If the points_scored or games_played values are negative, raise a ValueError with the message: "Points scored and games played must be non-negative!".
# * After a successful update, return a formatted string that confirms the update, displaying the player's updated stats.(use else)
#
# **Example:**
#
# *Input1:*
# ```python
# players = {
#     "LeBron James": {"position": "Forward", "points_scored": 27, "games_played": 50},
#     "Stephen Curry": {"position": "Guard", "points_scored": 30, "games_played": 50},
#     "Giannis Antetokounmpo": {"position": "Forward", "points_scored": 29, "games_played": 48}
# }
# player_name = "Stephen Curry"
# points_scored = 35
# games_played = 51
# ```
# *Input2:*
# ```python
# players = {
#     "LeBron James": {"position": "Forward", "points_scored": 27, "games_played": 50},
#     "Stephen Curry": {"position": "Guard", "points_scored": 30, "games_played": 50},
#     "Giannis Antetokounmpo": {"position": "Forward", "points_scored": 29, "games_played": 48}
# }
# player_name = "LeBron James"
# points_scored = -10
# games_played = 1
# ```
# *Output1:*
# <pre>
# "Stephen Curry has been updated: 65 points scored in 101 games."
# </pre>
#
# *Output2:*
# <pre>
# "Points scored and games played must be non-negative!"
# <pre>

# %%
players: Dict[str, Dict[str, Union[str,int]]] = {
    "LeBron James": {"position": "Forward", "points_scored": 27, "games_played": 50},
    "Stephen Curry": {"position": "Guard", "points_scored": 30, "games_played": 50},
    "Giannis Antetokounmpo": {"position": "Forward", "points_scored": 29, "games_played": 48}
}

player_name: str = "Stephen Curry"
points_scored: int= 35
games_played: int = 51

#// BEGIN_TODO [Basketball Team Roster Management ]

    #// END_TODO [Basketball Team Roster Management ]
try:
    print(update_player_stats(players, player_name, points_scored, games_played))
except KeyError as missing_player:
    print(missing_player)
except ValueError as invalid_scores:
    print(invalid_scores)
# Out:
# <cell>20: error: Unsupported operand types for + ("str" and "int")  [operator]
# <cell>20: note: Left operand is of type "str | int"
# <cell>21: error: Unsupported operand types for + ("str" and "int")  [operator]
# <cell>21: note: Left operand is of type "str | int"
# Stephen Curry has been updated: 65 points scored in 101 games.

# %% [markdown]
# ## Congratulations!
# You have finished your fifth Intro to Python Exercise notebook.

# %% [markdown]
# ---
#
# # (End of Notebook)
#
# &copy; 2020-2025 - **VU Amsterdam**
