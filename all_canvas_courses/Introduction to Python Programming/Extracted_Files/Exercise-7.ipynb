# %% [markdown]
# # Introduction to Python (# XB_0082) - Exercise 7 (2024-2025)
#
# This Exercise helps you practice with tuples, classes, and methods.

# %% [markdown]
# ## Table of Contents
# * [First Things First](#first)
# * [Important Reminder](#reminder)
# * [Preliminaries](#preliminaries)
# * [1. Open a Book](#exercise1)
# * [2. Actors](#exercise2)
# * [3. Matching Countries](#exercise3)
# * [4. Who's Who in Writing](#exercise4)
# * [5. Manchester Film Festival](#exercise5)
# * [6. Still More Books](#exercise6)
# * [7. Bookshelves](#exercise7)

# %% [markdown]
# ## First Things First <a class="anchor" id="first"></a>
#
# Add your name and student number in the next cell as strings stored in the `AUTHOR_NAME` and `STUDENT_NUMBER` variables.
#
# Please note that throughout the Exercises and Assignments, the commented lines containing `BEGIN_TODO` and `END_TODO` will mark where you need to start and finish writing your code. **ALWAYS WRITE YOUR SOLUTIONS WITHIN THESE MARKS** as code outside of them might not be graded!
#
# An example of what you could have in the next cell looks like this:
#
# ```python
# #// BEGIN_TODO [author] First Things First`
#
# AUTHOR_NAME = 'John Doe'
# STUDENT_NUMBER = '1234567'
#
# #// END_TODO [author] First Things First`
# ```

# %%
#// BEGIN_TODO [author]

AUTHOR_NAME = ''
STUDENT_NUMBER = ''

#// END_TODO [author]

# %% [markdown]
# ## Important Reminder <a class="anchor" id="reminder"></a>
#
# * Before jumping into coding, please note that you **NEED TO** follow all coding conventions defined on the Python Coding Standard document available via Canvas. Remember that you are not just programming for a *machine*, you are mainly programming for *other humans*!
#
#     * In particular, all variable declarations and function definitions must have **type hints**, and the latter a **docstring** as well.
#
#     * A *valid* docstring starts with a capital letter and ends with a dot.
#
# * Please also pay attention to the naming of your variables and the formatting of your output. The variable names and the output should match **exactly** with the examples given in each of the task descriptions to ensure that CodeGrade is able to grade your solution correctly.

# %% [markdown]
# ## Preliminaries <a class="anchor" id="preliminaries"></a>
#
# Run the cell below. This cell will import additional modules providing additional Python functionality.

# %%
# The lines starting with ! contain shell commands which install the extension Nb Mypy and its dependencies.
# Nb Mypy is a Jupyter extension which helps you automatically check type hinting in your notebooks.
# You only need to install these once: if you already did it (e.g., in the first Exercise notebook),
# then feel free to leave the two lines below commented.

#! python3 -m pip install mypy astor
#! python3 -m pip install nb_mypy

# This line loads the Nb Mypy extension in this notebook.
# %load_ext nb_mypy

# %%
from typing import List, Dict, Tuple, Set, Any, Union
from statistics import mean

# %% [markdown]
# ## 1. Open a Book <a class="anchor" id="exercise1"></a>
#
# In this Exercise, you will help create a system that categorizes books. Firstly, in this task, you should create a Python class named `Book`, which has one attribute, `title`, which should be passed as an argument when initializing a `Book` object. You do not need to add any methods besides the `__init__` method for now.
#
# It is enough that you define the `Book` class in this exercise. If you do it correctly, running the next cell will produce an output as shown in the example.
#
# **Example:**
#
# *Input:*
# ```python
# title: str = 'East of Eden'
# ```
#
# *Output:*
# <pre>
# Your book: East of Eden
# </pre>

# %%
title: str = 'East of Eden'

#// BEGIN_TODO [book] Open a Book

#// END_TODO [book]

book = Book(title)

print(f'Your book: {book.title}')

# %% [markdown]
# ## 2. Actors <a class="anchor" id="exercise2"></a>
#
# In this exercise, your task is to create a class named `Actor`. When initialized, it should take as argument the full name of the author as `name`, as well as their birth year as `birth_year`. Besides an `__init__` method, the class should have a [`__str__`](https://docs.python.org/3/reference/datamodel.html#object.__str__) method as well, which allows an `Actor` object to be neatly printed using their full name and their birthyear as in the example below (it needs to return a string).
#
# Once more, you have to define the `Actor` class in the specified way. The output as shown below will be generated by the code **outside** of the `TODO` area based on the class you create.
#
# **Example:**
#
# *Input:*
# ```python
# name: str = "Peter Dinklage"
# birth_year: int = 1969
# ```
#
# *Output:*
# <pre>
# Peter Dinklage, born in 1969.
# </pre>

# %%
name: str = "Peter Dinklage"
birth_year: int = 1969
#// BEGIN_TODO [actors] Actors

#// END_TODO [actors]

actor_one: Actor = Actor(name, birth_year)
print(f"{actor_one}")

# %% [markdown]
# ## 3. Matching Countries <a class="anchor" id="exercise3"></a>
#
# In this exercise, you will see some lines of code, but their order has been scrambled. Your job is to reconstruct the code by **ONLY PUTTING THE LINES IN THE CORRECT ORDER** and **NOT MODIFYING THEM**. You are not allowed to add or omit any lines of code, but you are of course allowed to add indentation.
#
# The program below can be used to check if two books originate from the same country. It contains the following components:
#
# * An updated `Author` class, which has attributes `name` and `country`.
#
# * An updated `Book` class, which has attributes `title` and `author`. Note that the attribute `author` is in fact an `Author` object!
#     * The class `Book` also has a method named `is_same_country()`, which takes as argument another `Book` object and returns `True` if both books' authors originate in the same country and `False` otherwise.
#
#     <br>
#
# * Additional code outside of the class definitions which checks if `East of Eden` and `Nineteen Eighty-Four` originate from the same country and prints a message accordingly.
#
# **Example:**
#
# *Input:*
# ```python
# book1 = Book('East of Eden', Author('John Steinbeck', 'US'))
# book2 = Book('Nineteen Eighty-Four', Author('George Orwell', 'UK'))
# ```
#
# *Output:*
# <pre>
# East of Eden is not from the same country as Nineteen Eighty-Four.
# </pre>
#
# The scrambled lines are given below. Do not worry if it seems a bit complex at first glance - these lines of code might be a little more advanced than what you have already tried doing on your own. You will get there soon though! In the meantime, use what you already know about Python to decide in which order the lines must come, and recreate the original code in the cell below.
#
# ```python
# def __init__(self, name:str, country:str) -> None:
#
# '''Represents a book.
#     :attributes: title, author
#     '''
#
# def is_same_country(self, other_book:Book) -> bool:
#
#
# '''Initializes an Author object.
#         :param: name: name of the author
#         :param: country: country of the author
#         '''
#
# def __init__(self, title:str, author:Author) -> None:
#
# '''Checks if two books come from the same country.
#         :param: other_book: the book to compare the current book with.
#         :return: a Boolean value showing if they are from the same country.
#         '''
#
# book1 = Book('East of Eden', Author('John Steinbeck', 'US'))
# book2 = Book('Nineteen Eighty-Four', Author('George Orwell', 'UK'))
#
# print(f'{book1.title} is not from the same country as {book2.title}.')
#
# self.name = name
# self.country = country
#
# '''Initializes a Book object.
#         :param: title: title of the book.
#         :param: author: author of the book
#         '''
#
# return self.author.country == other_book.author.country
#
#
# class Author:
#
#
#
#
# if book1.is_same_country(book2):
#
# '''Represents an author.
#     :attributes: name, country
#     '''
#
# class Book:
#
# self.title = title
# self.author = author
#
# else:
#
# print(f'{book1.title} is from the same country as {book2.title}.')
# ```

# %%
#// BEGIN_TODO [matching_countries] Matching Countries

#// END_TODO [matching_countries]

# %% [markdown]
# ## 4. Who's Who in Writing <a class="anchor" id="exercise5"></a>
#
# In this exercise, you will create a new version of the `Author` class which allows you to create objects representing authors and print their most important info in a neat message. Specifically, the class should work in the following way:
#
# * When initialized, it should take as argument the full name of the author as `name` as well as their birth year as `dob`, and it should create three instance attributes: the `first_name`, `last_name` and `birth_year` of the author. Pay attention that while the *full* name is passed as a parameter, the first and last names are stored in separate attributes! (You can assume that every author has a single first and last name and no middle names.)
#
# * It should include a `__str__` method which creates a string representation by returning the initial of the first name, the last name and the age of the author. E.g., John Grisham (born in 1955) would be represented as `J. Grisham, 68`.
#
# Your task is only to define this class - if you do it correctly, the additional code **outside** of the `TODO` will ensure that the output is as shown in the example.
#
# *Note:* make sure that the age is calculated correctly even if the program is run later, say, next year. In order to do this, you might need to import additional modules - feel free to do that in the next cell or add them to the second code cell in the *Preliminaries* section of this notebook (the one which imports from the typing and statistics module) and re-run that cell.
#
# Example:
#
# *Input:*
# ```python
# name: str = 'John Grisham'
# dob: int = 1955
# ```
#
# *Output:*
# <pre>
# A best-selling author: J. Grisham, 68
# </pre>

# %%
#// BEGIN_TODO [writing_whos_who] Who's Who in Writing

#// END_TODOD [writing_whos_who]

name: str = 'John Grisham'
dob: int = 1955

print(f'A best selling author: {Author(name, dob)}')

# %% [markdown]
# ## 5. Manchester Film Festival <a class="anchor" id="exercise5"></a>
#
# A film teacher taking their class to the Manchester Film Festival has come up with a game for their students to play. Each student has to take note of the films they have watched at the festival by taking notes of the film's title, main genre, setting, and country of production. The students that have watched enough different films such that they have at least seen movies of 4 different genres, years or production countries, will receive a small prize.
#
# In the exercise your task is to create a function `watch_films`, which takes as parameter a set of films a student has watched (`films_information`), and based on the details of the films evaluates whether the student is eligible for a prize or not. It does not return anything. If the student is eligible for a prize the function should print for which properties the student has 4 different values. If the student has not succeeded in watching enough different films, the function should print the statement `"Please keep watching different films!"`.
#
# Importantly, each of the films in the set passed as a parameter to the `watch_films()` function is represented as a tuple with four elements: the film's title, its genre, its setting, and its production.
#
# *Notes:*
# * It is alright if the order of the printed output is different than in the example (remember: sets are not ordered collections).
#
# Example:
#
# *Input:*
# ```python
# films: Set[Tuple[str,str,int,str]] = {
#     ("The Peanut Butter Falcon", "Adventure", 2019, "USA"),
#     ("Calibre", "Thriller", 2018, "UK"),
#     ("The Garden Left Behind", "Drama", 2019, "USA"),
#     ("Song of Granite", "Biographical", 2017, "Ireland/Canada"),
#     ("A Good Woman Is Hard to Find", "Thriller", 2019, "UK"),
# }
#
# ```
#
# *Output*
# <pre>
# You have at least 4 different genre values.
# Drama
# Thriller
# Adventure
# Biographical
# </pre>

# %%
films: Set[Tuple[str,str,int,str]] = {
    ("The Peanut Butter Falcon", "Adventure", 2019, "USA"),
    ("Calibre", "Thriller", 2018, "UK"),
    ("The Garden Left Behind", "Drama", 2019, "USA"),
    ("Song of Granite", "Biographical", 2017, "Ireland/Canada"),
    ("A Good Woman Is Hard to Find", "Thriller", 2019, "UK"),
}

#// BEGIN_TODO [manchester_film_festival] Manchester Film Festival

#// END_TODO [manchester_film_festival]
watch_films(films)

# %% [markdown]
# ## 6. Still More Books <a class="anchor" id="exercise6"></a>
#
# In this exercise, we will create more comprehensive version of the `Book` class.
#
# The init method should take the following parametres:
# * The title of the book as `title`.
# * The author of the book as `author`.
# * The year of publishing as `year`.
# * The genre of the book as `genre`.
# * The rating of the book as `rating`. The rating should be initialized to a float as `0.0`.
#
# It should have the following attributes:
# * Title of the book.
# * Author of the book, an `Author` object - you can reuse the `Author` class from the previous exercise. If you have already completed that one, there is no need to re-define it, just make sure to initialize its instances as specified in the previous exercise.
# * Year of the book.
# * Genre of the book.
# * Average rating of the book.
#
# Furthermore, it should include the following methods:
# * `__init__`: it should take as argument the title, the author (as an `Author` object), the genre, the year and the rating of the book. There are no default values for any of these parameters, except for the average rating, which can default to 0.0.
#
# * `__str__`: the string representation of a book is its title.
#
# * `is_similar`: this method takes as argument another Book object as `other_book` and checks if they are similar. Two books are similar if they are of the same genre and were published within 10 years of each other. The method should return a Boolean value.
#
# * `is_contemporary`: this method returns a Boolean value representing if the author of the book was born in or after 1940 (true) or not (false).
#
# You should create the `Book` class as specified above, then create two book objects as shown in the example. Furthermore, you should print:
# - `<book1> and <book2> are similar books.` if these two books are similar
# - and `<book1> and <book2> are not similar books.` otherwise.
#
# `<book1>` and `<book2>` refer to the string representations of the two `Book` objects.
#
# Example:
#
# *Input:*
# ```python
# book1 = Book('The Name of The Wind', Author('Patrick Rothfuss', 1973), 2007, 'fantasy', 4.5)
# book2 = Book('The Fifth Season', Author('Nora Jemisin', 1972), 2015, 'fantasy', 4.3)
# ```
#
# *Output:*
#
# <pre>
# The Name of The Wind and The Fifth Season are similar books.
# </pre>

# %%
#// BEGIN_TODO [more_books] Still More Books

#// END_TODO [more_books]

book1 = Book('The Name of The Wind', Author('Patrick Rothfuss', 1973), 2007, 'fantasy', 4.5)
book2 = Book('The Fifth Season', Author('Nora Jemisin', 1972), 2015, 'fantasy', 4.3)

if book1.is_similar(book2):
    print(f'{book1} and {book2} are similar books.')

else:
    print(f'{book1} and {book2} are not similar books.')

# %% [markdown]
# ## 7. Bookshelves <a class="anchor" id="exercise7"></a>
# In this exercise, you will create the class `Bookshelf`, which represents a reader's collection of books.
#
# The class `Bookshelf` should have the following attributes:
# * `books`, which is a list of `Book` objects representing the reader's favourite books. You should reuse the `Book` class defined in the previous exercise and **not** define it again. `books` is also passed as the parametre in the init method.
# * `name`, which is the reader's name. Again, also as a parametre in the init method.
# * `collection_name`, which is the name of the collection (e.g., *"Favourite books"*, *"Must read"*, etc.). And again, this also should be passed as a parametre in the init method.
#
# Furthermore, it should have the following methods:
# * `__init__`: it should take as parameter the list of books in the collection, the name of the reader and the name of the collection. The name of the reader and the name of the collection are mandatory, but the list of books is initialized as an empty list by default.
#
# * `__str__`: the string representation of a `Bookshelf` is the reader's name followed by the collection name (e.g., *"Joe's Must read"*).
#
# * `add_book`: this method appends a new Book object to the list of books on the shelf. It takes as argument the object as `new_book`.
#
# * `has_diverse_taste`: returns True if the book collection contains at least 3 genres, False otherwise.
#
# * `is_mostly_contemporary`: returns True if there are more contemporary books in the collection than not, False otherwise. Use the `Book` class's `is_contemporary` method.
#
# * `most_read_author`: returns the full name of the author who wrote the most books in the collection (as a string). If there is no such author (i.e., if all authors appear only once), it returns None. If there are several authors who wrote the most books (and more than 1), then it is alright only to return one of them.
#
# * `summarize`: this method prints a summary of the bookshelf in the following way:
#     * Print the string representation of the collection.
#     * If the bookshelf has a diverse taste, print `Diverse taste: YES`. Otherwise, print `Diverse taste: NO`.
#     * If the bookshelf is mostly contemporary, print: `Mostly contemporary: YES`. Otherwise, print `Mostly contemporary: NO`
#     * If the bookshelf has a most read author, print: `Most read author: <XY>` (where *\<XY\>* is the full name of the author). Otherwise, print `No most read author.`
#
# Use the `Bookshelf` class to create a collection of books as shown in the example below. Then, add the book *The Murder of Roger Ackroyd* to the collection. Finally, print a summary of the collection.
#
# *Hint:* The most challenging part of this exercise might be finding the most read author. For this, consider two hints:
#
# * Surprisingly, two objects with the same attributes from a costum class are not necessarily equal from Python's perspective (e.g., `Author('Stephen King', 1949) == Author('Stephen King', 1949)` will evaluate to `False`). This is because Python compares the memory references of costum objects instead of their contents. To avoid any complications arising from this, you can instead compare the names of authors as strings (e.g., `'Stephen King' == 'Stephen King'` will evaluate to `True`). Remember that the `Author` class we are using stores the first and last names as separate attributes - think about how to join them to create the full name as a string once more!
#
# * To find the most common element in a list, you might want to consider using the `Counter` class from the `collections` module. More specifically, check out how the `most_common` method of this class works. Remember that you will need to import this class if you want to use it!
#
# Example:
#
# *Input:*
#
# ```python
# book_list: List[Book] =[Book('Mr. Mercedes', Author('Stephen King', 1949), 2014, 'thriller', 4.0), \
#     Book('The Ten Thousand Doors of January', Author('Alix Harrow', 1989), 2019, 'adventure', 4.0), \
#         Book('The Call of the Wild', Author('Jack London', 1876), 1903, 'adventure', 3.9), \
#             Book('The Stand', Author('Stephen King', 1949), 1978, 'thriller', 4.4)]
#
# shelf = Bookshelf(name='Jane', collection_name='Read Last Year', books=book_list)
#
# new_book = Book('The Murder of Roger Ackroyd', Author('Agata Christie', 1890), 1926, 'mistery', 4.3)
# ```
#
# *Output:*
#
# <pre>
# Jane's Read Last Year:
# Diverse taste: YES
# Mostly contemporary: YES
# Most read author: Stephen King
# </pre>

# %%
#// BEGIN_TODO [bookshelves] Bookshelves
    
#// END_TODO [bookshelves]

# %% [markdown]
# ## Congratulations!
# You have finished your seventh Intro to Python Exercise notebook.

# %% [markdown]
# ---
#
# # (End of Notebook)
#
# &copy; 2020-2025 - **TU/e** - **VU Amsterdam**
