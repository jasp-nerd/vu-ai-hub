# %% [markdown]
# # Introduction to Python (# XB_0082) - Exercise 3 (2024-2025)
#
# The Third Exercise helps you practice for loops, while loops and lists.

# %% [markdown]
# ## Table of Contents
# * [First Things First](#first)
# * [Important Reminder](#reminder)
# * [Preliminaries](#preliminaries)
# * [1. Parking Hours](#exercise1)
# * [2. Perfect Squares](#exercise2)
# * [3. Astronauts](#exercise3)
# * [4. Donations](#exercise4)
# * [5. Dead Weight](#exercise5)
# * [6. Balloons](#exercise6)
# * [7. Lucky Letters](#exercise7)

# %% [markdown]
# ## First Things First <a class="anchor" id="first"></a>
#
# Add your name and student number in the next cell as strings stored in the `AUTHOR_NAME` and `STUDENT_NUMBER` variables.
#
# Please note that throughout the Exercises and Assignments, the commented lines containing `BEGIN_TODO` and `END_TODO` will mark where you need to start and finish writing your code. **ALWAYS WRITE YOUR SOLUTIONS WITHIN THESE MARKS** as code outside of them might not be graded!
#
# An example of what you could have in the next cell looks like this:
#
# ```python
# #// BEGIN_TODO [author] First Things First`
#
# AUTHOR_NAME = 'John Doe'
# STUDENT_NUMBER = '1234567'
#
# #// END_TODO [author] First Things First`
# ```

# %%
#// BEGIN_TODO [author]

AUTHOR_NAME = ''
STUDENT_NUMBER = ''

#// END_TODO [author]

# %% [markdown]
# ## Important Reminder <a class="anchor" id="reminder"></a>
#
# * Before jumping into coding, please note that you **NEED TO** follow all coding conventions defined on the Python Coding Standard document available via Canvas. Remember that you are not just programming for a *machine*, you are mainly programming for *other humans*!
#
#     * In particular, all variable declarations and function definitions must have **type hints**, and the latter a **docstring** as well.
#
#     * A *valid* docstring starts with a capital letter and ends with a dot.
#
# * Please also pay attention to the naming of your variables and the formatting of your output. The variable names and the output should match **exactly** with the examples given in each of the task descriptions to ensure that CodeGrade is able to grade your solution correctly.

# %% [markdown]
# ## Preliminaries <a class="anchor" id="preliminaries"></a>
#
# Run the cell below. This cell will import additional modules providing additional Python functionality.

# %%
# The lines starting with ! contain shell commands which install the extension Nb Mypy and its dependencies.
# Nb Mypy is a Jupyter extension which helps you automatically check type hinting in your notebooks.
# You only need to install these once: if you already did it (e.g., in the first Exercise notebook),
# then feel free to leave the two lines below commented.

#! python3 -m pip install mypy astor
#! python3 -m pip install nb_mypy

# This line loads the Nb Mypy extension in this notebook.
# %load_ext nb_mypy

# %%
from typing import List

# %% [markdown]
# ## 1. Parking Hours <a class="anchor" id="exercise1"></a>
#
# In the town square cars are allowed to park only during daytime, so that a parking ban starts at a given hour of each evening. Your task is to write a Python function called `parking_hours` that takes two parameters as input: `start_parking` which is the hour when a car starts parking, and `start_ban`, which is the hour when the parking ban begins. The function should print `PARKING OK` for each hour from the start of the parking until the start of the ban.
#
# **Notes:**
# * You should use a `while` loop in your code.
# * Both the start of the parking time and the start of the ban should be taken in whole hours, so as an integer between 0 and 23, stored in the `start_parking` and `start_ban` variables, respectively.
# * As in the example, the hour should be printed in the message as well.
#
# **Example:**
#
# *Input:*
# ```python
# start_parking: int = 16
# start_ban: int = 19
# ```
#
# *Output:*
# <pre>
# 16h: PARKING OK
# 17h: PARKING OK
# 18h: PARKING OK
#
# </pre>

# %%
start_parking: int = 16
start_ban: int = 19

#// BEGIN_TODO [parking_hours] Parking Hours

#// END_TODO [parking_hours]

parking_hours(start_parking, start_ban)

# %% [markdown]
# ## 2. Perfect Squares <a class="anchor" id="exercise2"></a>
#
# In fifth grade, pupils start to practice powers, starting with squares and cubes. In this exercise, implement a function called `squares` that takes as input a parameter named `last_number`, which is an integer, and prints the squares of integers from 1 to `last_number`.
#
# **Note:** You should use a `for` loop in your code.
#
# **Example:**
#
# *Input:*
# ```python
# last_number: int = 5
# ```
#
# *Output:*
# <pre>
# 1 ^ 2 = 1
# 2 ^ 2 = 4
# 3 ^ 2 = 9
# 4 ^ 2 = 16
# 5 ^ 2 = 25
# </pre>

# %%
last_number: int = 5

#// BEGIN_TODO [squares] Perfect Squares

#// END_TODO [squares]

squares(last_number)

# %% [markdown]
# ## 3. Astronauts <a class="anchor" id="exercise3"></a>
#
# In this exercise, you will see some lines of code, but their order has been scrambled. Your job is to reconstruct the code by **ONLY PUTTING THE LINES IN THE CORRECT ORDER** and **NOT MODIFYING THEM**. You are not allowed to add or omit any lines of code, but you are of course allowed to add indentation.
#
# This particular program helps solve a problem related to minimizing the weight carried by a spaceship. It is a small ship carrying only crew members and no cargo. This program takes as input the weight capacity of the spaceship as well as a list which contains the body weights of available astronauts in kilograms and calculates the maximum number of astronauts which might be carried by this ship without exceeding the weight limit. As well as printing the result, the program also saves the maximum number of astronauts in a float variable named `nr_to_carry`.
#
# **Example:**
#
# *Input:*
# ```python
# capacity: float = 350.0
# body_weights: List[float] = [98.5, 63.2, 76.6, 55.8, 83.4, 87.5, 79.9, 65.3]
# ```
#
# *Output:*
# <pre>
# Maximum number of astronauts to carry: 5
# </pre>
#
# The scrambled lines are given below. Do not worry if it seems a bit complex at first glance - these lines of code might be a little more advanced than what you have already tried doing on your own. You will get there soon though! In the meantime, use what you already know about Python to decide in which order the lines must come, and recreate the original code in the cell below.
#
# ```python
#
# total_weight += weight
#
# body_weights.sort()
#
# break
#
# if total_weight + weight <= capacity:
#
# print(f'Maximum number of astronauts to carry: {nr_to_carry}')
#
# """
# Determines and prints the maximum number of astronauts that can be carried
# on a spaceship without exceeding the capacity.
# :param: capacity is a float for the weight capacity of the spaceship.
# :param: body_weights is a list that contains the weights of the astronauts.
# :return: None.
# """
#
# total_weight: float = 0.0
#
# for weight in body_weights:
#
# nr_to_carry += 1
#
# else:
#
# def discard_people(capacity: float, body_weights: List[float]) -> None:
#
# nr_to_carry: int = 0
# ```

# %%
capacity_example: float = 350.0
body_weights_example: List[float] = [98.5, 63.2, 76.6, 55.8, 83.4, 87.5, 79.9, 65.3]

#// BEGIN_TODO [astronauts] Astronauts

#// END_TODO [astronauts]

discard_people(capacity_example, body_weights_example)

# %% [markdown]
# ## 4. Donations <a class="anchor" id="exercise4"></a>
#
# Visitors to the theme park can donate small amounts to a charity when they buy their tickets. The park managament has set a goal that they want to raise EUR 1000 in donations. The following program simulates this process and declares when the goal has been reached. For each day from the start of the fundraising campaign, it takes the amount of that day's donations from user input and reports the amount of money raised so far. Once the goal has been reached, the program prints a message about it and terminates.
#
# An example of how the program works:
#
# *Input:*
#
# ```python
# goal: float = 1000.0
# ```
#
# <pre>
# How much money was raised on day 1? 347
# How much money was raised on day 2? 200
# How much money was raised on day 3? 410
# How much money was raised on day 4? 192
# </pre>
#
# *Output:*
#
# <pre>
# Total money raised by day 1: EUR 347
# Total money raised by day 2: EUR 547
# Total money raised by day 3: EUR 957
# GOAL REACHED ON DAY 4 WITH A TOTAL OF EUR 1149
# </pre>
#
# The code for this program is shown below. However, this code is buggy: when you run it (by copying it into the next cell), it does not work properly. Your task is to find the mistake(s) in the code and correct them in the next cell. Please note that **you should also correct mistakes which allow the code to run** (e.g., think about proper type-hinting...).
#
# **Note:**
# * The program SHOULD allow for donations that are not whole Euros (e.g., EUR 15.6), but the amounts in the output should be rounded to whole Euros.
#
# ```python
# total_raised: float = 0.0
# day: float = 1
#
# while total_raised < goal:
#     if day > 0:
#         print(f'Total money raised by day {day}: EUR {total_raised:.0f}')
#
#     raised_today: float = input(f'How much money was raised on day {day}?')
#
# total_raised += raised_today
#
# day += 1
#
# print(f'GOAL REACHED ON DAY {day} WITH A TOTAL OF EUR {total_raised:.0f}')
# ```

# %%
goal: float = 1000.0

#// BEGIN_TODO [donations] Donations

#// END_TODOD [donations]

# %% [markdown]
# ## 5. Dead Weight <a class="anchor" id="exercise5"></a>
#
# On one of the longer planet-to-planet trips, some of the objects carried on board of the spaceship will need to be discarded to allow the crew to carry more fuel with them. In this exercise, your task is to write a function `discard_cargo` which takes as argument a list of objects carried on board `cargo` (ordered so that more important items are at the front of the list and less important ones come after) and prints the items which will be discarded. The rule is that every object which comes in the second half of the list (so the less important half) will be discarded.
#
# *Notes:*
# * If there are an odd number of items in the list, more should be discarded than kept.
# * Do not import additional libraries for this task.
# * You should use a `for` loop in your code.
# * Store the number of items you will **keep** in an integer variable named `nr_to_keep`. You should use this variable for list slicing when selecting the items to discard.
#
# **Example:**
#
# *Input:*
# ```python
# cargo_example: List[str] = ['food pills', 'water skins', 'toolbox', 'galactic map', 'pencils', 'board games', 'socks']
# ```
#
# *Output:*
# <pre>
# Items to discard:
# galactic map
# pencils
# board games
# socks
# </pre>

# %%
cargo_example: List[str] = ['food pills', 'water skins', 'toolbox', 'galactic map', 'pencils', 'board games', 'socks']

#// BEGIN_TODO [dead_weight] Dead Weight

#// END_TODO [dead_weight]

discard_cargo(cargo_example)

# %% [markdown]
# ## 6. Balloons <a class="anchor" id="exercise6"></a>
#
# The lines for the rides in the Carnival can be very long. To make the waiting time a little more pleasant, Carnival clowns are handing out a given number of balloons every ten minutes. Your task is to write a function named `balloons` which keeps track of the time passed in line as well as the number of balloons handed out in each 10-minute interval. The function should work as follows:
#
# * It should take as input two parameters: `waiting_time` which is the total waiting time in the line in minutes and `nr_balloons` which is the number of balloons given out every ten minutes.
# * It should count the minutes passed in line (the counter should be a variable called `time_passed`), and at every 10th minute, it should print `X MINUTE BALLOON TIME!`, with `X` the number of minutes passed so far.
# * Furthermore, also at every 10th minute, the program should count the number of balloons which have been handed out (the counter should be a variable called `balloons_out`) and print the message `Y balloons handed out` (with `Y` the number of balloons handed out so far in that period) until all the balloons for that 10-minute interval are gone.
#
# *Note:*
# * Include an empty line in your output between the players to increase readability. Use `print('')` for checking purposes.
# * You should use `while` loops in your code.
#
# Example:
#
# *Input:*
# ```python
# waiting_time: int = 30
# nr_balloons: int = 3
# ```
#
# *Output:*
#
# <pre>
# 10 MINUTE BALLOON TIME!
# 1 balloons handed out
# 2 balloons handed out
# 3 balloons handed out
#
# 20 MINUTE BALLOON TIME!
# 1 balloons handed out
# 2 balloons handed out
# 3 balloons handed out
#
# 30 MINUTE BALLOON TIME!
# 1 balloons handed out
# 2 balloons handed out
# 3 balloons handed out
# </pre>

# %%
waiting_time: int = 30
nr_balloons: int = 3

#// BEGIN_TODO [balloons] Balloons


#// END_TODO [balloons]

balloons(waiting_time, nr_balloons)

# %% [markdown]
# ## 7. Lucky Letters <a class="anchor" id="exercise7"></a>
#
# For a class trip, the children invent a game to entertain themselves on the bus ride. The game goes as follows:
#
# * Five "lucky" and three "unlucky" letters are selected from the alphabet by a judge, who is a different kid in each round of the game.
# * Everyone counts the number of lucky and unlucky letters in their own full names. A lucky letter is worth +3 points, and an unlucky letter is worth -2 points (each occurrence counts). This way, everybody calculates their own number of points.
# * Additionally, if your total number of points is divisible by 3, you get 2 extra points.
# * The children with the highest number of points wins.
#
# Implement a Python function called `letter_game` which imitates this game. It should take as input three parameters: `lucky` which is a string of lucky letters, `unlucky`which is a string of unlucky letters, and `players` which is a list of player names. For each player calculate the number of points they would get in this game.
#
# As output, the function should print the name of the winner and their number of points.
#
# *Notes:*
# * You should use `for` loops in your code.
# * You should **not** use lists or dictionaries to keep track of the player points (think of another way to "remember" who is the current winner).
#
# Example:
#
# *Input:*
#
# ```python
# lucky: str = 'BEOKS'
# unlucky: str = 'ATL'
# players: List[str] = ['Frodo Baggins', 'Samwise Gamgee', 'Pippin Took', 'Merry Brandybuck']
# ```
#
# *Output:*
#
# <pre>
# Winner: Samwise Gamgee
# Total points: 11
# </pre>

# %%
lucky: str = 'BEOKS'
unlucky: str = 'ATL'
players: List[str] = ['Frodo Baggins', 'Samwise Gamgee', 'Pippin Took', 'Merry Brandybuck']

#// BEGIN_TODO [lucky_letters] Lucky Letters

#// END_TODO [lucky_letters]

letter_game(lucky, unlucky, players)

# %% [markdown]
# ## Congratulations!
# You have finished your Third Intro to Python Exercise notebook.

# %% [markdown]
# ---
#
# # (End of Notebook)
#
# &copy; 2020-2025 - **TU/e** - **VU Amsterdam**
